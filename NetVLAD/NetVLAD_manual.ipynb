# %% [markdown]
# <a href="https://colab.research.google.com/github/engineerjkk/-/blob/main/NetVLAD/NetVLAD_manual.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [***출처: 심현주님의 블로그를 참고했습니다.***](https://medium.com/hyunjulie/%EC%BA%90%EA%B8%80%EA%B3%BC-%EA%B5%AC%EA%B8%80-colab-%EC%97%B0%EA%B2%B0%ED%95%B4%EC%A3%BC%EA%B8%B0-6a274f6de81d)
#
#
# **1. 먼저 본인의 캐글 계정에서 API Token 을 다운받습니다.**
#
# ![업로드방법](https://cdn-images-1.medium.com/max/800/1*yvocb2Sbyf_ZbBxUcJM7rA.png)
#
# **오른쪽 상단에서 My Account 에 들어갑니다**
#
# ![API받기](https://cdn-images-1.medium.com/max/800/1*JgVnYqQh6mEEoKCLayFz9g.png)
#
# **Create New API Token 을 누르면 kaggle.json 파일이 다운로드 됩니다. 이 파일은 찾기 쉬운곳에 일단 옮겨두고,**
#
# **아래의 셀을 실행합니다. 여기서 '파일선택'을 누르고 kaggle.json을 업로드합니다.**

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-0e4e9926-3f45-4f50-ad1d-4abb40da70f7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0e4e9926-3f45-4f50-ad1d-4abb40da70f7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"kangjunekoo","key":"dbbd6a4f5f963a0ddccbb10bea8288c9"}'}

# %%
# json 파일 옮겨주기
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# Permission Warning 이 일어나지 않도록 
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d socome/netvlad-landmark-dataset-sejong
# !unzip netvlad-landmark-dataset-sejong.zip
# !tar -xvzf Sejong.tgz
# Out:
# Downloading netvlad-landmark-dataset-sejong.zip to /content
#  98% 1.51G/1.53G [00:44<00:00, 28.5MB/s]
# 100% 1.53G/1.53G [00:44<00:00, 37.1MB/s]
# Archive:  netvlad-landmark-dataset-sejong.zip
#   inflating: Sejong.tgz
# Sejong/
# Sejong/test/
# Sejong/train/
# Sejong/test/AI/
# Sejong/test/Clock tower/
# Sejong/test/desktop.ini
# Sejong/test/Front door Child/
# Sejong/test/Front door Sejong/
# Sejong/test/Museum/
# Sejong/test/Stone statue/
# Sejong/train/AI/
# Sejong/train/Clock tower/
# Sejong/train/desktop.ini
# Sejong/train/Front door Child/
# Sejong/train/Front door Sejong/
# Sejong/train/Museum/
# Sejong/train/Stone statue/
# Sejong/test/AI/1245_1167_139.jpg
# Sejong/test/AI/42523.png
# Sejong/test/AI/clip20190606_1620_45_379.png
# Sejong/test/AI/desktop.ini
# Sejong/test/AI/대양 4.png
# Sejong/test/AI/대양.jpg
# Sejong/test/AI/대양.PNG
# Sejong/test/AI/대양2.png
# Sejong/test/AI/대양22.PNG
# Sejong/test/AI/대양3.png
# Sejong/test/AI/대양33.PNG
# Sejong/test/AI/대양4.PNG
# Sejong/test/AI/대양5.png
# Sejong/test/AI/대양6.png
# Sejong/test/AI/대양67.png
# Sejong/test/Clock tower/182388_63837_2045.jpg
# Sejong/test/Clock tower/2.jpg
# Sejong/test/Clock tower/20151016_103810_edit.jpg
# Sejong/test/Clock tower/da17bb39ff8ae1a87e2182d53ec2656d.gif
# Sejong/test/Clock tower/desktop.ini
# Sejong/test/Clock tower/DSC08927.jpeg
# Sejong/test/Clock tower/htm_2016122293339878068.jpg
# Sejong/test/Clock tower/IMAGE0107.jpg
# Sejong/test/Clock tower/images (2).jpeg
# Sejong/test/Clock tower/image_readtop_2017_466166_14997999662951835.jpg
# Sejong/test/Clock tower/IMGP0092.jpeg
# Sejong/test/Clock tower/IMG_9553.jpeg
# Sejong/test/Clock tower/SNC13649.jpeg
# Sejong/test/Clock tower/visual02.jpg
# Sejong/test/Clock tower/다운로드.jpeg
# Sejong/test/Clock tower/세종대.jpg
# Sejong/test/Clock tower/세종대학교에서.jpg
# Sejong/test/Clock tower/시계탑 1.PNG
# Sejong/test/Clock tower/시계탑 2.PNG
# Sejong/test/Clock tower/시계탑 3.PNG
# Sejong/test/Clock tower/시계탑 4.PNG
# Sejong/test/Clock tower/시계탑.PNG
# Sejong/test/Clock tower/시계탑2.PNG
# Sejong/test/Clock tower/캡처.PNG
# Sejong/test/Front door Child/desktop.ini
# Sejong/test/Front door Child/어대1.jpg
# Sejong/test/Front door Child/어대2.jpg
# Sejong/test/Front door Child/어대3.jpg
# Sejong/test/Front door Child/어대4.jpg
# Sejong/test/Front door Child/어대5.jpg
# Sejong/test/Front door Child/어대정문 1.PNG
# Sejong/test/Front door Child/어대정문 2.PNG
# Sejong/test/Front door Child/어대정문 3.PNG
# Sejong/test/Front door Child/어대정문 4.PNG
# Sejong/test/Front door Child/어대정문 5.PNG
# Sejong/test/Front door Child/어대정문.gif
# Sejong/test/Front door Child/어대정문2.png
# Sejong/test/Front door Child/어대정문3.jpg
# Sejong/test/Front door Child/어대정문4.jpg
# Sejong/test/Front door Child/어대정문5.jpg
# Sejong/test/Front door Sejong/11591591_2.jpg
# Sejong/test/Front door Sejong/15222_1.jpg
# Sejong/test/Front door Sejong/171124021658584_thumb_400.jpg
# Sejong/test/Front door Sejong/32050-2-28580.jpg
# Sejong/test/Front door Sejong/59345518_416184742506506_1078728709059494141_n.jpg
# Sejong/test/Front door Sejong/87766_90856_2830.jpg
# Sejong/test/Front door Sejong/99B4B1395B344F5E32.png
# Sejong/test/Front door Sejong/daemun.png
# Sejong/test/Front door Sejong/desktop.ini
# Sejong/test/Front door Sejong/I96-F194z1ykJ3JuIC1uRPS3JDFg.jpg
# Sejong/test/Front door Sejong/images.jpeg
# Sejong/test/Front door Sejong/IMG_0598.jpeg
# Sejong/test/Front door Sejong/naver_com_20140123_235813.jpg
# Sejong/test/Front door Sejong/SejongGate.jpg
# Sejong/test/Front door Sejong/다운로드 (1).jpeg
# Sejong/test/Front door Sejong/세종대1.png
# Sejong/test/Front door Sejong/세종대_창의인재_(2).png
# Sejong/test/Front door Sejong/세종대수시13.jpg
# Sejong/test/Front door Sejong/세종대학교_(10).jpeg
# Sejong/test/Front door Sejong/정문 1.PNG
# Sejong/test/Front door Sejong/정문 2.PNG
# Sejong/test/Front door Sejong/정문 3.PNG
# Sejong/test/Front door Sejong/정문 4.PNG
# Sejong/test/Front door Sejong/정문 5.PNG
# Sejong/test/Front door Sejong/정문 6.PNG
# Sejong/test/Museum/171124021658675_thumb_400.jpg
# Sejong/test/Museum/20131231_134850.jpg
# Sejong/test/Museum/2014-01-05_17.20.49.jpg
# Sejong/test/Museum/400_125979639932490.jpg
# Sejong/test/Museum/400_125979639933931.jpg
# Sejong/test/Museum/campus_tour2.jpg
# Sejong/test/Museum/desktop.ini
# Sejong/test/Museum/DSC04953.jpg
# Sejong/test/Museum/GetImage.jpeg
# Sejong/test/Museum/images (1).jpeg
# Sejong/test/Museum/SNC13658.jpeg
# Sejong/test/Museum/박물관 1.PNG
# Sejong/test/Museum/박물관 2.PNG
# Sejong/test/Museum/박물관 3.PNG
# Sejong/test/Museum/박물관 4.PNG
# Sejong/test/Museum/박물관 5.PNG
# Sejong/test/Museum/박물관 6.PNG
# Sejong/test/Museum/세종대학교박물관.jpg
# Sejong/test/Stone statue/desktop.ini
# Sejong/test/Stone statue/석상 1.PNG
# Sejong/test/Stone statue/석상 2.PNG
# Sejong/test/Stone statue/석상.jpg
# Sejong/test/Stone statue/석상.PNG
# Sejong/test/Stone statue/석상2.jpg
# Sejong/test/Stone statue/석상2.PNG
# Sejong/test/Stone statue/석상3.PNG
# Sejong/train/AI/desktop.ini
# Sejong/train/AI/IMAGE0000.jpg
# Sejong/train/AI/IMAGE0001.jpg
# Sejong/train/AI/IMAGE0002.jpg
# Sejong/train/AI/IMAGE0003.jpg
# Sejong/train/AI/IMAGE0004.jpg
# Sejong/train/AI/IMAGE0005.jpg
# Sejong/train/AI/IMAGE0006.jpg
# Sejong/train/AI/IMAGE0007.jpg
# Sejong/train/AI/IMAGE0008.jpg
# Sejong/train/AI/IMAGE0009.jpg
# Sejong/train/AI/IMAGE0010.jpg
# Sejong/train/AI/IMAGE0011.jpg
# Sejong/train/AI/IMAGE0012.jpg
# Sejong/train/AI/IMAGE0013.jpg
# Sejong/train/AI/IMAGE0014.jpg
# Sejong/train/AI/IMAGE0015.jpg
# Sejong/train/AI/IMAGE0016.jpg
# Sejong/train/AI/IMAGE0017.jpg
# Sejong/train/AI/IMAGE0018.jpg
# Sejong/train/AI/IMAGE0019.jpg
# Sejong/train/AI/IMAGE0020.jpg
# Sejong/train/AI/IMAGE0021.jpg
# Sejong/train/AI/IMAGE0022.jpg
# Sejong/train/AI/IMAGE0023.jpg
# Sejong/train/AI/IMAGE0024.jpg
# Sejong/train/AI/IMAGE0025.jpg
# Sejong/train/AI/IMAGE0026.jpg
# Sejong/train/AI/IMAGE0027.jpg
# Sejong/train/AI/IMAGE0028.jpg
# Sejong/train/AI/IMAGE0029.jpg
# Sejong/train/AI/IMAGE0030.jpg
# Sejong/train/AI/IMAGE0031.jpg
# Sejong/train/AI/IMAGE0032.jpg
# Sejong/train/AI/IMAGE0033.jpg
# Sejong/train/AI/IMAGE0034.jpg
# Sejong/train/AI/IMAGE0035.jpg
# Sejong/train/AI/IMAGE0036.jpg
# Sejong/train/AI/IMAGE0037.jpg
# Sejong/train/AI/IMAGE0038.jpg
# Sejong/train/AI/IMAGE0039.jpg
# Sejong/train/AI/IMAGE0040.jpg
# Sejong/train/AI/IMAGE0041.jpg
# Sejong/train/AI/IMAGE0042.jpg
# Sejong/train/AI/IMAGE0043.jpg
# Sejong/train/AI/IMAGE0044.jpg
# Sejong/train/AI/IMAGE0045.jpg
# Sejong/train/AI/IMAGE0046.jpg
# Sejong/train/AI/IMAGE0047.jpg
# Sejong/train/AI/IMAGE0048.jpg
# Sejong/train/AI/IMAGE0049.jpg
# Sejong/train/AI/IMAGE0050.jpg
# Sejong/train/AI/IMAGE0051.jpg
# Sejong/train/AI/IMAGE0052.jpg
# Sejong/train/AI/IMAGE0053.jpg
# Sejong/train/AI/IMAGE0054.jpg
# Sejong/train/AI/IMAGE0055.jpg
# Sejong/train/AI/IMAGE0056.jpg
# Sejong/train/AI/IMAGE0057.jpg
# Sejong/train/AI/IMAGE0058.jpg
# Sejong/train/AI/IMAGE0059.jpg
# Sejong/train/AI/IMAGE0060.jpg
# Sejong/train/AI/IMAGE0061.jpg
# Sejong/train/AI/IMAGE0062.jpg
# Sejong/train/AI/IMAGE0063.jpg
# Sejong/train/AI/IMAGE0064.jpg
# Sejong/train/AI/IMAGE0065.jpg
# Sejong/train/AI/IMAGE0066.jpg
# Sejong/train/AI/IMAGE0067.jpg
# Sejong/train/AI/IMAGE0068.jpg
# Sejong/train/AI/IMAGE0069.jpg
# Sejong/train/AI/IMAGE0070.jpg
# Sejong/train/AI/IMAGE0071.jpg
# Sejong/train/AI/IMAGE0072.jpg
# Sejong/train/AI/IMAGE0073.jpg
# Sejong/train/AI/IMAGE0074.jpg
# Sejong/train/AI/IMAGE0075.jpg
# Sejong/train/AI/IMAGE0076.jpg
# Sejong/train/AI/IMAGE0077.jpg
# Sejong/train/AI/IMAGE0078.jpg
# Sejong/train/AI/IMAGE0079.jpg
# Sejong/train/AI/IMAGE0080.jpg
# Sejong/train/AI/IMAGE0081.jpg
# Sejong/train/AI/IMAGE0082.jpg
# Sejong/train/AI/IMAGE0083.jpg
# Sejong/train/AI/IMAGE0084.jpg
# Sejong/train/AI/IMAGE0085.jpg
# Sejong/train/AI/IMAGE0086.jpg
# Sejong/train/AI/IMAGE0087.jpg
# Sejong/train/AI/IMAGE0088.jpg
# Sejong/train/AI/IMAGE0089.jpg
# Sejong/train/AI/IMAGE0090.jpg
# Sejong/train/AI/IMAGE0091.jpg
# Sejong/train/AI/IMAGE0092.jpg
# Sejong/train/AI/IMAGE0093.jpg
# Sejong/train/AI/IMAGE0094.jpg
# Sejong/train/AI/IMAGE0095.jpg
# Sejong/train/AI/IMAGE0096.jpg
# Sejong/train/AI/IMAGE0097.jpg
# Sejong/train/AI/IMAGE0098.jpg
# Sejong/train/AI/IMAGE0099.jpg
# Sejong/train/AI/IMAGE0100.jpg
# Sejong/train/AI/IMAGE0101.jpg
# Sejong/train/AI/IMAGE0102.jpg
# Sejong/train/AI/IMAGE0103.jpg
# Sejong/train/AI/IMAGE0104.jpg
# Sejong/train/AI/IMAGE0105.jpg
# Sejong/train/AI/IMAGE0106.jpg
# Sejong/train/AI/IMAGE0107.jpg
# Sejong/train/AI/IMAGE0108.jpg
# Sejong/train/AI/IMAGE0109.jpg
# Sejong/train/AI/IMAGE0110.jpg
# Sejong/train/AI/IMAGE0111.jpg
# Sejong/train/AI/IMAGE0112.jpg
# Sejong/train/AI/IMAGE0113.jpg
# Sejong/train/AI/IMAGE0114.jpg
# Sejong/train/AI/IMAGE0115.jpg
# Sejong/train/AI/IMAGE0116.jpg
# Sejong/train/AI/IMAGE0117.jpg
# Sejong/train/AI/IMAGE0118.jpg
# Sejong/train/AI/IMAGE0119.jpg
# Sejong/train/AI/IMAGE0120.jpg
# Sejong/train/AI/IMAGE0121.jpg
# Sejong/train/AI/IMAGE0122.jpg
# Sejong/train/AI/IMAGE0123.jpg
# Sejong/train/AI/IMAGE0124.jpg
# Sejong/train/AI/IMAGE0125.jpg
# Sejong/train/AI/IMAGE0126.jpg
# Sejong/train/AI/IMAGE0127.jpg
# Sejong/train/AI/IMAGE0128.jpg
# Sejong/train/AI/IMAGE0129.jpg
# Sejong/train/AI/IMAGE0130.jpg
# Sejong/train/AI/IMAGE0131.jpg
# Sejong/train/AI/IMAGE0132.jpg
# Sejong/train/AI/IMAGE0133.jpg
# Sejong/train/AI/IMAGE0134.jpg
# Sejong/train/AI/IMAGE0135.jpg
# Sejong/train/AI/IMAGE0136.jpg
# Sejong/train/AI/IMAGE0137.jpg
# Sejong/train/AI/IMAGE0138.jpg
# Sejong/train/AI/IMAGE0139.jpg
# Sejong/train/AI/IMAGE0140.jpg
# Sejong/train/AI/IMAGE0141.jpg
# Sejong/train/AI/IMAGE0142.jpg
# Sejong/train/AI/IMAGE0143.jpg
# Sejong/train/AI/IMAGE0144.jpg
# Sejong/train/AI/IMAGE0145.jpg
# Sejong/train/AI/IMAGE0146.jpg
# Sejong/train/AI/IMAGE0147.jpg
# Sejong/train/AI/IMAGE0148.jpg
# Sejong/train/AI/IMAGE0149.jpg
# Sejong/train/AI/IMAGE0150.jpg
# Sejong/train/AI/IMAGE0151.jpg
# Sejong/train/AI/IMAGE0152.jpg
# Sejong/train/AI/IMAGE0153.jpg
# Sejong/train/AI/IMAGE0154.jpg
# Sejong/train/AI/IMAGE0155.jpg
# Sejong/train/AI/IMAGE0156.jpg
# Sejong/train/AI/IMAGE0157.jpg
# Sejong/train/AI/IMAGE0158.jpg
# Sejong/train/AI/IMAGE0159.jpg
# Sejong/train/AI/IMAGE0160.jpg
# Sejong/train/AI/IMAGE0161.jpg
# Sejong/train/AI/IMAGE0162.jpg
# Sejong/train/AI/IMAGE0163.jpg
# Sejong/train/AI/IMAGE0164.jpg
# Sejong/train/AI/IMAGE0165.jpg
# Sejong/train/AI/IMAGE0166.jpg
# Sejong/train/AI/IMAGE0167.jpg
# Sejong/train/AI/IMAGE0168.jpg
# Sejong/train/AI/IMAGE0169.jpg
# Sejong/train/AI/IMAGE0170.jpg
# Sejong/train/AI/IMAGE0171.jpg
# Sejong/train/AI/IMAGE0172.jpg
# Sejong/train/AI/IMAGE0173.jpg
# Sejong/train/AI/IMAGE0174.jpg
# Sejong/train/AI/IMAGE0175.jpg
# Sejong/train/AI/IMAGE0176.jpg
# Sejong/train/AI/IMAGE0178.jpg
# Sejong/train/AI/IMAGE0180.jpg
# Sejong/train/AI/IMAGE0181.jpg
# Sejong/train/AI/IMAGE0182.jpg
# Sejong/train/AI/IMAGE0183.jpg
# Sejong/train/Clock tower/desktop.ini
# Sejong/train/Clock tower/IMAGE0000.jpg
# Sejong/train/Clock tower/IMAGE0001.jpg
# Sejong/train/Clock tower/IMAGE0002.jpg
# Sejong/train/Clock tower/IMAGE0003.jpg
# Sejong/train/Clock tower/IMAGE0004.jpg
# Sejong/train/Clock tower/IMAGE0005.jpg
# Sejong/train/Clock tower/IMAGE0006.jpg
# Sejong/train/Clock tower/IMAGE0007.jpg
# Sejong/train/Clock tower/IMAGE0008.jpg
# Sejong/train/Clock tower/IMAGE0009.jpg
# Sejong/train/Clock tower/IMAGE0010.jpg
# Sejong/train/Clock tower/IMAGE0011.jpg
# Sejong/train/Clock tower/IMAGE0012.jpg
# Sejong/train/Clock tower/IMAGE0013.jpg
# Sejong/train/Clock tower/IMAGE0014.jpg
# Sejong/train/Clock tower/IMAGE0015.jpg
# Sejong/train/Clock tower/IMAGE0016.jpg
# Sejong/train/Clock tower/IMAGE0017.jpg
# Sejong/train/Clock tower/IMAGE0018.jpg
# Sejong/train/Clock tower/IMAGE0019.jpg
# Sejong/train/Clock tower/IMAGE0020.jpg
# Sejong/train/Clock tower/IMAGE0021.jpg
# Sejong/train/Clock tower/IMAGE0022.jpg
# Sejong/train/Clock tower/IMAGE0023.jpg
# Sejong/train/Clock tower/IMAGE0024.jpg
# Sejong/train/Clock tower/IMAGE0025.jpg
# Sejong/train/Clock tower/IMAGE0026.jpg
# Sejong/train/Clock tower/IMAGE0027.jpg
# Sejong/train/Clock tower/IMAGE0028.jpg
# Sejong/train/Clock tower/IMAGE0029.jpg
# Sejong/train/Clock tower/IMAGE0030.jpg
# Sejong/train/Clock tower/IMAGE0031.jpg
# Sejong/train/Clock tower/IMAGE0032.jpg
# Sejong/train/Clock tower/IMAGE0033.jpg
# Sejong/train/Clock tower/IMAGE0034.jpg
# Sejong/train/Clock tower/IMAGE0035.jpg
# Sejong/train/Clock tower/IMAGE0036.jpg
# Sejong/train/Clock tower/IMAGE0037.jpg
# Sejong/train/Clock tower/IMAGE0038.jpg
# Sejong/train/Clock tower/IMAGE0039.jpg
# Sejong/train/Clock tower/IMAGE0040.jpg
# Sejong/train/Clock tower/IMAGE0041.jpg
# Sejong/train/Clock tower/IMAGE0042.jpg
# Sejong/train/Clock tower/IMAGE0043.jpg
# Sejong/train/Clock tower/IMAGE0044.jpg
# Sejong/train/Clock tower/IMAGE0045.jpg
# Sejong/train/Clock tower/IMAGE0046.jpg
# Sejong/train/Clock tower/IMAGE0047.jpg
# Sejong/train/Clock tower/IMAGE0048.jpg
# Sejong/train/Clock tower/IMAGE0049.jpg
# Sejong/train/Clock tower/IMAGE0050.jpg
# Sejong/train/Clock tower/IMAGE0051.jpg
# Sejong/train/Clock tower/IMAGE0052.jpg
# Sejong/train/Clock tower/IMAGE0053.jpg
# Sejong/train/Clock tower/IMAGE0054.jpg
# Sejong/train/Clock tower/IMAGE0055.jpg
# Sejong/train/Clock tower/IMAGE0056.jpg
# Sejong/train/Clock tower/IMAGE0057.jpg
# Sejong/train/Clock tower/IMAGE0058.jpg
# Sejong/train/Clock tower/IMAGE0059.jpg
# Sejong/train/Clock tower/IMAGE0060.jpg
# Sejong/train/Clock tower/IMAGE0061.jpg
# Sejong/train/Clock tower/IMAGE0062.jpg
# Sejong/train/Clock tower/IMAGE0063.jpg
# Sejong/train/Clock tower/IMAGE0064.jpg
# Sejong/train/Clock tower/IMAGE0065.jpg
# Sejong/train/Clock tower/IMAGE0066.jpg
# Sejong/train/Clock tower/IMAGE0067.jpg
# Sejong/train/Clock tower/IMAGE0068.jpg
# Sejong/train/Clock tower/IMAGE0069.jpg
# Sejong/train/Clock tower/IMAGE0070.jpg
# Sejong/train/Clock tower/IMAGE0071.jpg
# Sejong/train/Clock tower/IMAGE0072.jpg
# Sejong/train/Clock tower/IMAGE0073.jpg
# Sejong/train/Clock tower/IMAGE0074.jpg
# Sejong/train/Clock tower/IMAGE0075.jpg
# Sejong/train/Clock tower/IMAGE0076.jpg
# Sejong/train/Clock tower/IMAGE0077.jpg
# Sejong/train/Clock tower/IMAGE0078.jpg
# Sejong/train/Clock tower/IMAGE0079.jpg
# Sejong/train/Clock tower/IMAGE0080.jpg
# Sejong/train/Clock tower/IMAGE0081.jpg
# Sejong/train/Clock tower/IMAGE0082.jpg
# Sejong/train/Clock tower/IMAGE0083.jpg
# Sejong/train/Clock tower/IMAGE0084.jpg
# Sejong/train/Clock tower/IMAGE0085.jpg
# Sejong/train/Clock tower/IMAGE0086.jpg
# Sejong/train/Clock tower/IMAGE0087.jpg
# Sejong/train/Clock tower/IMAGE0088.jpg
# Sejong/train/Clock tower/IMAGE0089.jpg
# Sejong/train/Clock tower/IMAGE0090.jpg
# Sejong/train/Clock tower/IMAGE0091.jpg
# Sejong/train/Clock tower/IMAGE0092.jpg
# Sejong/train/Clock tower/IMAGE0093.jpg
# Sejong/train/Clock tower/IMAGE0094.jpg
# Sejong/train/Clock tower/IMAGE0095.jpg
# Sejong/train/Clock tower/IMAGE0096.jpg
# Sejong/train/Clock tower/IMAGE0097.jpg
# Sejong/train/Clock tower/IMAGE0098.jpg
# Sejong/train/Clock tower/IMAGE0099.jpg
# Sejong/train/Clock tower/IMAGE0100.jpg
# Sejong/train/Clock tower/IMAGE0101.jpg
# Sejong/train/Clock tower/IMAGE0102.jpg
# Sejong/train/Clock tower/IMAGE0103.jpg
# Sejong/train/Clock tower/IMAGE0104.jpg
# Sejong/train/Clock tower/IMAGE0105.jpg
# Sejong/train/Clock tower/IMAGE0106.jpg
# Sejong/train/Clock tower/IMAGE0108.jpg
# Sejong/train/Front door Child/desktop.ini
# Sejong/train/Front door Child/IMAGE0000.jpg
# Sejong/train/Front door Child/IMAGE0001.jpg
# Sejong/train/Front door Child/IMAGE0002.jpg
# Sejong/train/Front door Child/IMAGE0003.jpg
# Sejong/train/Front door Child/IMAGE0004.jpg
# Sejong/train/Front door Child/IMAGE0005.jpg
# Sejong/train/Front door Child/IMAGE0006.jpg
# Sejong/train/Front door Child/IMAGE0007.jpg
# Sejong/train/Front door Child/IMAGE0008.jpg
# Sejong/train/Front door Child/IMAGE0009.jpg
# Sejong/train/Front door Child/IMAGE0010.jpg
# Sejong/train/Front door Child/IMAGE0011.jpg
# Sejong/train/Front door Child/IMAGE0012.jpg
# Sejong/train/Front door Child/IMAGE0013.jpg
# Sejong/train/Front door Child/IMAGE0014.jpg
# Sejong/train/Front door Child/IMAGE0015.jpg
# Sejong/train/Front door Child/IMAGE0016.jpg
# Sejong/train/Front door Child/IMAGE0017.jpg
# Sejong/train/Front door Child/IMAGE0018.jpg
# Sejong/train/Front door Child/IMAGE0019.jpg
# Sejong/train/Front door Child/IMAGE0020.jpg
# Sejong/train/Front door Child/IMAGE0021.jpg
# Sejong/train/Front door Child/IMAGE0022.jpg
# Sejong/train/Front door Child/IMAGE0023.jpg
# Sejong/train/Front door Child/IMAGE0024.jpg
# Sejong/train/Front door Child/IMAGE0025.jpg
# Sejong/train/Front door Child/IMAGE0026.jpg
# Sejong/train/Front door Child/IMAGE0027.jpg
# Sejong/train/Front door Child/IMAGE0028.jpg
# Sejong/train/Front door Child/IMAGE0029.jpg
# Sejong/train/Front door Child/IMAGE0030.jpg
# Sejong/train/Front door Child/IMAGE0031.jpg
# Sejong/train/Front door Child/IMAGE0032.jpg
# Sejong/train/Front door Child/IMAGE0033.jpg
# Sejong/train/Front door Child/IMAGE0034.jpg
# Sejong/train/Front door Child/IMAGE0035.jpg
# Sejong/train/Front door Child/IMAGE0036.jpg
# Sejong/train/Front door Child/IMAGE0037.jpg
# Sejong/train/Front door Child/IMAGE0038.jpg
# Sejong/train/Front door Child/IMAGE0039.jpg
# Sejong/train/Front door Child/IMAGE0040.jpg
# Sejong/train/Front door Child/IMAGE0041.jpg
# Sejong/train/Front door Child/IMAGE0042.jpg
# Sejong/train/Front door Child/IMAGE0043.jpg
# Sejong/train/Front door Child/IMAGE0044.jpg
# Sejong/train/Front door Child/IMAGE0045.jpg
# Sejong/train/Front door Child/IMAGE0046.jpg
# Sejong/train/Front door Child/IMAGE0047.jpg
# Sejong/train/Front door Child/IMAGE0048.jpg
# Sejong/train/Front door Child/IMAGE0049.jpg
# Sejong/train/Front door Child/IMAGE0050.jpg
# Sejong/train/Front door Child/IMAGE0051.jpg
# Sejong/train/Front door Child/IMAGE0052.jpg
# Sejong/train/Front door Child/IMAGE0053.jpg
# Sejong/train/Front door Child/IMAGE0054.jpg
# Sejong/train/Front door Child/IMAGE0055.jpg
# Sejong/train/Front door Child/IMAGE0056.jpg
# Sejong/train/Front door Child/IMAGE0057.jpg
# Sejong/train/Front door Child/IMAGE0058.jpg
# Sejong/train/Front door Child/IMAGE0059.jpg
# Sejong/train/Front door Child/IMAGE0060.jpg
# Sejong/train/Front door Child/IMAGE0061.jpg
# Sejong/train/Front door Child/IMAGE0062.jpg
# Sejong/train/Front door Child/IMAGE0063.jpg
# Sejong/train/Front door Child/IMAGE0064.jpg
# Sejong/train/Front door Child/IMAGE0065.jpg
# Sejong/train/Front door Child/IMAGE0066.jpg
# Sejong/train/Front door Child/IMAGE0067.jpg
# Sejong/train/Front door Child/IMAGE0068.jpg
# Sejong/train/Front door Child/IMAGE0069.jpg
# Sejong/train/Front door Child/IMAGE0070.jpg
# Sejong/train/Front door Child/IMAGE0071.jpg
# Sejong/train/Front door Child/IMAGE0072.jpg
# Sejong/train/Front door Child/IMAGE0073.jpg
# Sejong/train/Front door Child/IMAGE0074.jpg
# Sejong/train/Front door Child/IMAGE0075.jpg
# Sejong/train/Front door Child/IMAGE0076.jpg
# Sejong/train/Front door Child/IMAGE0077.jpg
# Sejong/train/Front door Child/IMAGE0078.jpg
# Sejong/train/Front door Child/IMAGE0079.jpg
# Sejong/train/Front door Child/IMAGE0080.jpg
# Sejong/train/Front door Child/IMAGE0081.jpg
# Sejong/train/Front door Child/IMAGE0082.jpg
# Sejong/train/Front door Child/IMAGE0083.jpg
# Sejong/train/Front door Child/IMAGE0084.jpg
# Sejong/train/Front door Child/IMAGE0085.jpg
# Sejong/train/Front door Child/IMAGE0086.jpg
# Sejong/train/Front door Child/IMAGE0087.jpg
# Sejong/train/Front door Child/IMAGE0088.jpg
# Sejong/train/Front door Child/IMAGE0089.jpg
# Sejong/train/Front door Child/IMAGE0090.jpg
# Sejong/train/Front door Child/IMAGE0091.jpg
# Sejong/train/Front door Child/IMAGE0092.jpg
# Sejong/train/Front door Child/IMAGE0093.jpg
# Sejong/train/Front door Child/IMAGE0094.jpg
# Sejong/train/Front door Child/IMAGE0095.jpg
# Sejong/train/Front door Child/IMAGE0096.jpg
# Sejong/train/Front door Child/IMAGE0097.jpg
# Sejong/train/Front door Child/IMAGE0098.jpg
# Sejong/train/Front door Child/IMAGE0099.jpg
# Sejong/train/Front door Child/IMAGE0100.jpg
# Sejong/train/Front door Child/IMAGE0101.jpg
# Sejong/train/Front door Child/IMAGE0102.jpg
# Sejong/train/Front door Child/IMAGE0103.jpg
# Sejong/train/Front door Child/IMAGE0104.jpg
# Sejong/train/Front door Child/IMAGE0105.jpg
# Sejong/train/Front door Child/IMAGE0106.jpg
# Sejong/train/Front door Child/IMAGE0107.jpg
# Sejong/train/Front door Child/IMAGE0108.jpg
# Sejong/train/Front door Child/IMAGE0109.jpg
# Sejong/train/Front door Child/IMAGE0110.jpg
# Sejong/train/Front door Child/IMAGE0111.jpg
# Sejong/train/Front door Child/IMAGE0112.jpg
# Sejong/train/Front door Child/IMAGE0113.jpg
# Sejong/train/Front door Child/IMAGE0114.jpg
# Sejong/train/Front door Child/IMAGE0115.jpg
# Sejong/train/Front door Child/IMAGE0116.jpg
# Sejong/train/Front door Child/IMAGE0117.jpg
# Sejong/train/Front door Child/IMAGE0118.jpg
# Sejong/train/Front door Child/IMAGE0119.jpg
# Sejong/train/Front door Child/IMAGE0120.jpg
# Sejong/train/Front door Child/IMAGE0121.jpg
# Sejong/train/Front door Child/IMAGE0122.jpg
# Sejong/train/Front door Child/IMAGE0123.jpg
# Sejong/train/Front door Child/IMAGE0124.jpg
# Sejong/train/Front door Child/IMAGE0125.jpg
# Sejong/train/Front door Child/IMAGE0126.jpg
# Sejong/train/Front door Child/IMAGE0127.jpg
# Sejong/train/Front door Child/IMAGE0128.jpg
# Sejong/train/Front door Child/IMAGE0129.jpg
# Sejong/train/Front door Child/IMAGE0130.jpg
# Sejong/train/Front door Child/IMAGE0131.jpg
# Sejong/train/Front door Child/IMAGE0132.jpg
# Sejong/train/Front door Child/IMAGE0133.jpg
# Sejong/train/Front door Child/IMAGE0134.jpg
# Sejong/train/Front door Child/IMAGE0135.jpg
# Sejong/train/Front door Child/IMAGE0136.jpg
# Sejong/train/Front door Child/IMAGE0137.jpg
# Sejong/train/Front door Child/IMAGE0138.jpg
# Sejong/train/Front door Child/IMAGE0139.jpg
# Sejong/train/Front door Child/IMAGE0140.jpg
# Sejong/train/Front door Child/IMAGE0141.jpg
# Sejong/train/Front door Child/IMAGE0142.jpg
# Sejong/train/Front door Child/IMAGE0143.jpg
# Sejong/train/Front door Child/IMAGE0144.jpg
# Sejong/train/Front door Child/IMAGE0145.jpg
# Sejong/train/Front door Child/IMAGE0146.jpg
# Sejong/train/Front door Child/IMAGE0147.jpg
# Sejong/train/Front door Child/IMAGE0148.jpg
# Sejong/train/Front door Child/IMAGE0149.jpg
# Sejong/train/Front door Child/IMAGE0150.jpg
# Sejong/train/Front door Child/IMAGE0151.jpg
# Sejong/train/Front door Child/IMAGE0152.jpg
# Sejong/train/Front door Child/IMAGE0153.jpg
# Sejong/train/Front door Child/IMAGE0154.jpg
# Sejong/train/Front door Child/IMAGE0155.jpg
# Sejong/train/Front door Child/IMAGE0156.jpg
# Sejong/train/Front door Child/IMAGE0157.jpg
# Sejong/train/Front door Child/IMAGE0158.jpg
# Sejong/train/Front door Child/IMAGE0159.jpg
# Sejong/train/Front door Child/IMAGE0160.jpg
# Sejong/train/Front door Child/IMAGE0161.jpg
# Sejong/train/Front door Child/IMAGE0162.jpg
# Sejong/train/Front door Child/IMAGE0163.jpg
# Sejong/train/Front door Child/IMAGE0164.jpg
# Sejong/train/Front door Child/IMAGE0165.jpg
# Sejong/train/Front door Child/IMAGE0166.jpg
# Sejong/train/Front door Child/IMAGE0167.jpg
# Sejong/train/Front door Child/IMAGE0168.jpg
# Sejong/train/Front door Child/IMAGE0169.jpg
# Sejong/train/Front door Sejong/desktop.ini
# Sejong/train/Front door Sejong/IMAGE0000.jpg
# Sejong/train/Front door Sejong/IMAGE0001.jpg
# Sejong/train/Front door Sejong/IMAGE0002.jpg
# Sejong/train/Front door Sejong/IMAGE0003.jpg
# Sejong/train/Front door Sejong/IMAGE0004.jpg
# Sejong/train/Front door Sejong/IMAGE0005.jpg
# Sejong/train/Front door Sejong/IMAGE0006.jpg
# Sejong/train/Front door Sejong/IMAGE0007.jpg
# Sejong/train/Front door Sejong/IMAGE0008.jpg
# Sejong/train/Front door Sejong/IMAGE0009.jpg
# Sejong/train/Front door Sejong/IMAGE0010.jpg
# Sejong/train/Front door Sejong/IMAGE0011.jpg
# Sejong/train/Front door Sejong/IMAGE0012.jpg
# Sejong/train/Front door Sejong/IMAGE0013.jpg
# Sejong/train/Front door Sejong/IMAGE0014.jpg
# Sejong/train/Front door Sejong/IMAGE0015.jpg
# Sejong/train/Front door Sejong/IMAGE0016.jpg
# Sejong/train/Front door Sejong/IMAGE0017.jpg
# Sejong/train/Front door Sejong/IMAGE0018.jpg
# Sejong/train/Front door Sejong/IMAGE0019.jpg
# Sejong/train/Front door Sejong/IMAGE0020.jpg
# Sejong/train/Front door Sejong/IMAGE0021.jpg
# Sejong/train/Front door Sejong/IMAGE0022.jpg
# Sejong/train/Front door Sejong/IMAGE0023.jpg
# Sejong/train/Front door Sejong/IMAGE0024.jpg
# Sejong/train/Front door Sejong/IMAGE0025.jpg
# Sejong/train/Front door Sejong/IMAGE0026.jpg
# Sejong/train/Front door Sejong/IMAGE0027.jpg
# Sejong/train/Front door Sejong/IMAGE0028.jpg
# Sejong/train/Front door Sejong/IMAGE0029.jpg
# Sejong/train/Front door Sejong/IMAGE0030.jpg
# Sejong/train/Front door Sejong/IMAGE0031.jpg
# Sejong/train/Front door Sejong/IMAGE0032.jpg
# Sejong/train/Front door Sejong/IMAGE0033.jpg
# Sejong/train/Front door Sejong/IMAGE0034.jpg
# Sejong/train/Front door Sejong/IMAGE0035.jpg
# Sejong/train/Front door Sejong/IMAGE0036.jpg
# Sejong/train/Front door Sejong/IMAGE0037.jpg
# Sejong/train/Front door Sejong/IMAGE0038.jpg
# Sejong/train/Front door Sejong/IMAGE0039.jpg
# Sejong/train/Front door Sejong/IMAGE0040.jpg
# Sejong/train/Front door Sejong/IMAGE0041.jpg
# Sejong/train/Front door Sejong/IMAGE0042.jpg
# Sejong/train/Front door Sejong/IMAGE0043.jpg
# Sejong/train/Front door Sejong/IMAGE0044.jpg
# Sejong/train/Front door Sejong/IMAGE0045.jpg
# Sejong/train/Front door Sejong/IMAGE0046.jpg
# Sejong/train/Front door Sejong/IMAGE0047.jpg
# Sejong/train/Front door Sejong/IMAGE0048.jpg
# Sejong/train/Front door Sejong/IMAGE0049.jpg
# Sejong/train/Front door Sejong/IMAGE0050.jpg
# Sejong/train/Front door Sejong/IMAGE0051.jpg
# Sejong/train/Front door Sejong/IMAGE0052.jpg
# Sejong/train/Front door Sejong/IMAGE0053.jpg
# Sejong/train/Front door Sejong/IMAGE0054.jpg
# Sejong/train/Front door Sejong/IMAGE0055.jpg
# Sejong/train/Front door Sejong/IMAGE0056.jpg
# Sejong/train/Front door Sejong/IMAGE0057.jpg
# Sejong/train/Front door Sejong/IMAGE0058.jpg
# Sejong/train/Front door Sejong/IMAGE0059.jpg
# Sejong/train/Front door Sejong/IMAGE0060.jpg
# Sejong/train/Front door Sejong/IMAGE0061.jpg
# Sejong/train/Front door Sejong/IMAGE0062.jpg
# Sejong/train/Front door Sejong/IMAGE0063.jpg
# Sejong/train/Front door Sejong/IMAGE0064.jpg
# Sejong/train/Front door Sejong/IMAGE0065.jpg
# Sejong/train/Front door Sejong/IMAGE0066.jpg
# Sejong/train/Front door Sejong/IMAGE0067.jpg
# Sejong/train/Front door Sejong/IMAGE0068.jpg
# Sejong/train/Front door Sejong/IMAGE0069.jpg
# Sejong/train/Front door Sejong/IMAGE0070.jpg
# Sejong/train/Front door Sejong/IMAGE0071.jpg
# Sejong/train/Front door Sejong/IMAGE0072.jpg
# Sejong/train/Front door Sejong/IMAGE0073.jpg
# Sejong/train/Front door Sejong/IMAGE0074.jpg
# Sejong/train/Front door Sejong/IMAGE0075.jpg
# Sejong/train/Front door Sejong/IMAGE0076.jpg
# Sejong/train/Front door Sejong/IMAGE0077.jpg
# Sejong/train/Front door Sejong/IMAGE0078.jpg
# Sejong/train/Front door Sejong/IMAGE0079.jpg
# Sejong/train/Front door Sejong/IMAGE0080.jpg
# Sejong/train/Front door Sejong/IMAGE0081.jpg
# Sejong/train/Front door Sejong/IMAGE0082.jpg
# Sejong/train/Front door Sejong/IMAGE0083.jpg
# Sejong/train/Front door Sejong/IMAGE0084.jpg
# Sejong/train/Front door Sejong/IMAGE0085.jpg
# Sejong/train/Front door Sejong/IMAGE0086.jpg
# Sejong/train/Front door Sejong/IMAGE0087.jpg
# Sejong/train/Front door Sejong/IMAGE0088.jpg
# Sejong/train/Front door Sejong/IMAGE0089.jpg
# Sejong/train/Front door Sejong/IMAGE0090.jpg
# Sejong/train/Front door Sejong/IMAGE0091.jpg
# Sejong/train/Front door Sejong/IMAGE0092.jpg
# Sejong/train/Front door Sejong/IMAGE0093.jpg
# Sejong/train/Front door Sejong/IMAGE0094.jpg
# Sejong/train/Front door Sejong/IMAGE0095.jpg
# Sejong/train/Front door Sejong/IMAGE0096.jpg
# Sejong/train/Front door Sejong/IMAGE0097.jpg
# Sejong/train/Museum/desktop.ini
# Sejong/train/Museum/IMAGE0000.jpg
# Sejong/train/Museum/IMAGE0001.jpg
# Sejong/train/Museum/IMAGE0002.jpg
# Sejong/train/Museum/IMAGE0003.jpg
# Sejong/train/Museum/IMAGE0004.jpg
# Sejong/train/Museum/IMAGE0005.jpg
# Sejong/train/Museum/IMAGE0006.jpg
# Sejong/train/Museum/IMAGE0007.jpg
# Sejong/train/Museum/IMAGE0008.jpg
# Sejong/train/Museum/IMAGE0009.jpg
# Sejong/train/Museum/IMAGE0010.jpg
# Sejong/train/Museum/IMAGE0011.jpg
# Sejong/train/Museum/IMAGE0012.jpg
# Sejong/train/Museum/IMAGE0013.jpg
# Sejong/train/Museum/IMAGE0014.jpg
# Sejong/train/Museum/IMAGE0015.jpg
# Sejong/train/Museum/IMAGE0016.jpg
# Sejong/train/Museum/IMAGE0017.jpg
# Sejong/train/Museum/IMAGE0018.jpg
# Sejong/train/Museum/IMAGE0019.jpg
# Sejong/train/Museum/IMAGE0020.jpg
# Sejong/train/Museum/IMAGE0021.jpg
# Sejong/train/Museum/IMAGE0022.jpg
# Sejong/train/Museum/IMAGE0023.jpg
# Sejong/train/Museum/IMAGE0024.jpg
# Sejong/train/Museum/IMAGE0025.jpg
# Sejong/train/Museum/IMAGE0026.jpg
# Sejong/train/Museum/IMAGE0027.jpg
# Sejong/train/Museum/IMAGE0028.jpg
# Sejong/train/Museum/IMAGE0029.jpg
# Sejong/train/Museum/IMAGE0030.jpg
# Sejong/train/Museum/IMAGE0031.jpg
# Sejong/train/Museum/IMAGE0032.jpg
# Sejong/train/Museum/IMAGE0033.jpg
# Sejong/train/Museum/IMAGE0034.jpg
# Sejong/train/Museum/IMAGE0035.jpg
# Sejong/train/Museum/IMAGE0036.jpg
# Sejong/train/Museum/IMAGE0037.jpg
# Sejong/train/Museum/IMAGE0038.jpg
# Sejong/train/Museum/IMAGE0039.jpg
# Sejong/train/Museum/IMAGE0040.jpg
# Sejong/train/Museum/IMAGE0041.jpg
# Sejong/train/Museum/IMAGE0042.jpg
# Sejong/train/Museum/IMAGE0043.jpg
# Sejong/train/Museum/IMAGE0044.jpg
# Sejong/train/Museum/IMAGE0045.jpg
# Sejong/train/Museum/IMAGE0046.jpg
# Sejong/train/Museum/IMAGE0047.jpg
# Sejong/train/Museum/IMAGE0048.jpg
# Sejong/train/Museum/IMAGE0049.jpg
# Sejong/train/Museum/IMAGE0050.jpg
# Sejong/train/Museum/IMAGE0051.jpg
# Sejong/train/Museum/IMAGE0052.jpg
# Sejong/train/Museum/IMAGE0053.jpg
# Sejong/train/Museum/IMAGE0054.jpg
# Sejong/train/Museum/IMAGE0055.jpg
# Sejong/train/Museum/IMAGE0056.jpg
# Sejong/train/Museum/IMAGE0057.jpg
# Sejong/train/Museum/IMAGE0058.jpg
# Sejong/train/Museum/IMAGE0059.jpg
# Sejong/train/Museum/IMAGE0060.jpg
# Sejong/train/Museum/IMAGE0061.jpg
# Sejong/train/Museum/IMAGE0062.jpg
# Sejong/train/Museum/IMAGE0063.jpg
# Sejong/train/Museum/IMAGE0064.jpg
# Sejong/train/Museum/IMAGE0065.jpg
# Sejong/train/Museum/IMAGE0066.jpg
# Sejong/train/Museum/IMAGE0067.jpg
# Sejong/train/Museum/IMAGE0068.jpg
# Sejong/train/Museum/IMAGE0069.jpg
# Sejong/train/Museum/IMAGE0070.jpg
# Sejong/train/Museum/IMAGE0071.jpg
# Sejong/train/Museum/IMAGE0072.jpg
# Sejong/train/Museum/IMAGE0073.jpg
# Sejong/train/Museum/IMAGE0074.jpg
# Sejong/train/Museum/IMAGE0075.jpg
# Sejong/train/Museum/IMAGE0076.jpg
# Sejong/train/Museum/IMAGE0077.jpg
# Sejong/train/Museum/IMAGE0078.jpg
# Sejong/train/Museum/IMAGE0079.jpg
# Sejong/train/Museum/IMAGE0080.jpg
# Sejong/train/Museum/IMAGE0081.jpg
# Sejong/train/Museum/IMAGE0082.jpg
# Sejong/train/Museum/IMAGE0083.jpg
# Sejong/train/Museum/IMAGE0084.jpg
# Sejong/train/Museum/IMAGE0085.jpg
# Sejong/train/Museum/IMAGE0086.jpg
# Sejong/train/Museum/IMAGE0087.jpg
# Sejong/train/Museum/IMAGE0088.jpg
# Sejong/train/Museum/IMAGE0089.jpg
# Sejong/train/Museum/IMAGE0090.jpg
# Sejong/train/Museum/IMAGE0091.jpg
# Sejong/train/Museum/IMAGE0092.jpg
# Sejong/train/Museum/IMAGE0093.jpg
# Sejong/train/Museum/IMAGE0094.jpg
# Sejong/train/Museum/IMAGE0095.jpg
# Sejong/train/Museum/IMAGE0096.jpg
# Sejong/train/Museum/IMAGE0097.jpg
# Sejong/train/Museum/IMAGE0098.jpg
# Sejong/train/Museum/IMAGE0099.jpg
# Sejong/train/Museum/IMAGE0100.jpg
# Sejong/train/Museum/IMAGE0101.jpg
# Sejong/train/Museum/IMAGE0102.jpg
# Sejong/train/Museum/IMAGE0103.jpg
# Sejong/train/Museum/IMAGE0104.jpg
# Sejong/train/Museum/IMAGE0105.jpg
# Sejong/train/Museum/IMAGE0106.jpg
# Sejong/train/Museum/IMAGE0107.jpg
# Sejong/train/Museum/IMAGE0108.jpg
# Sejong/train/Museum/IMAGE0109.jpg
# Sejong/train/Stone statue/desktop.ini
# Sejong/train/Stone statue/IMAGE0000.jpg
# Sejong/train/Stone statue/IMAGE0001.jpg
# Sejong/train/Stone statue/IMAGE0002.jpg
# Sejong/train/Stone statue/IMAGE0003.jpg
# Sejong/train/Stone statue/IMAGE0004.jpg
# Sejong/train/Stone statue/IMAGE0005.jpg
# Sejong/train/Stone statue/IMAGE0006.jpg
# Sejong/train/Stone statue/IMAGE0007.jpg
# Sejong/train/Stone statue/IMAGE0008.jpg
# Sejong/train/Stone statue/IMAGE0009.jpg
# Sejong/train/Stone statue/IMAGE0010.jpg
# Sejong/train/Stone statue/IMAGE0011.jpg
# Sejong/train/Stone statue/IMAGE0012.jpg
# Sejong/train/Stone statue/IMAGE0013.jpg
# Sejong/train/Stone statue/IMAGE0014.jpg
# Sejong/train/Stone statue/IMAGE0015.jpg
# Sejong/train/Stone statue/IMAGE0016.jpg
# Sejong/train/Stone statue/IMAGE0017.jpg
# Sejong/train/Stone statue/IMAGE0018.jpg
# Sejong/train/Stone statue/IMAGE0019.jpg
# Sejong/train/Stone statue/IMAGE0020.jpg
# Sejong/train/Stone statue/IMAGE0021.jpg
# Sejong/train/Stone statue/IMAGE0022.jpg
# Sejong/train/Stone statue/IMAGE0023.jpg
# Sejong/train/Stone statue/IMAGE0024.jpg
# Sejong/train/Stone statue/IMAGE0025.jpg
# Sejong/train/Stone statue/IMAGE0026.jpg
# Sejong/train/Stone statue/IMAGE0027.jpg
# Sejong/train/Stone statue/IMAGE0028.jpg
# Sejong/train/Stone statue/IMAGE0029.jpg
# Sejong/train/Stone statue/IMAGE0030.jpg
# Sejong/train/Stone statue/IMAGE0031.jpg
# Sejong/train/Stone statue/IMAGE0032.jpg
# Sejong/train/Stone statue/IMAGE0033.jpg
# Sejong/train/Stone statue/IMAGE0034.jpg
# Sejong/train/Stone statue/IMAGE0035.jpg
# Sejong/train/Stone statue/IMAGE0036.jpg
# Sejong/train/Stone statue/IMAGE0037.jpg
# Sejong/train/Stone statue/IMAGE0038.jpg
# Sejong/train/Stone statue/IMAGE0039.jpg
# Sejong/train/Stone statue/IMAGE0040.jpg
# Sejong/train/Stone statue/IMAGE0041.jpg
# Sejong/train/Stone statue/IMAGE0042.jpg
# Sejong/train/Stone statue/IMAGE0043.jpg
# Sejong/train/Stone statue/IMAGE0044.jpg
# Sejong/train/Stone statue/IMAGE0045.jpg
# Sejong/train/Stone statue/IMAGE0046.jpg
# Sejong/train/Stone statue/IMAGE0047.jpg
# Sejong/train/Stone statue/IMAGE0048.jpg
# Sejong/train/Stone statue/IMAGE0049.jpg
# Sejong/train/Stone statue/IMAGE0050.jpg
# Sejong/train/Stone statue/IMAGE0051.jpg
# Sejong/train/Stone statue/IMAGE0052.jpg
# Sejong/train/Stone statue/IMAGE0053.jpg
# Sejong/train/Stone statue/IMAGE0054.jpg
# Sejong/train/Stone statue/IMAGE0055.jpg
# Sejong/train/Stone statue/IMAGE0056.jpg
# Sejong/train/Stone statue/IMAGE0057.jpg
# Sejong/train/Stone statue/IMAGE0058.jpg
# Sejong/train/Stone statue/IMAGE0059.jpg
# Sejong/train/Stone statue/IMAGE0060.jpg
# Sejong/train/Stone statue/IMAGE0061.jpg
# Sejong/train/Stone statue/IMAGE0062.jpg
# Sejong/train/Stone statue/IMAGE0063.jpg
# Sejong/train/Stone statue/IMAGE0064.jpg
# Sejong/train/Stone statue/IMAGE0065.jpg
# Sejong/train/Stone statue/IMAGE0066.jpg
# Sejong/train/Stone statue/IMAGE0067.jpg
# Sejong/train/Stone statue/IMAGE0068.jpg
# Sejong/train/Stone statue/IMAGE0069.jpg
# Sejong/train/Stone statue/IMAGE0070.jpg
# Sejong/train/Stone statue/IMAGE0071.jpg
# Sejong/train/Stone statue/IMAGE0072.jpg
# Sejong/train/Stone statue/IMAGE0073.jpg
# Sejong/train/Stone statue/IMAGE0074.jpg
# Sejong/train/Stone statue/IMAGE0075.jpg
# Sejong/train/Stone statue/IMAGE0076.jpg
# Sejong/train/Stone statue/IMAGE0077.jpg
# Sejong/train/Stone statue/IMAGE0078.jpg
# Sejong/train/Stone statue/IMAGE0079.jpg
# Sejong/train/Stone statue/IMAGE0080.jpg
# Sejong/train/Stone statue/IMAGE0081.jpg
# Sejong/train/Stone statue/IMAGE0082.jpg
# Sejong/train/Stone statue/IMAGE0083.jpg
# Sejong/train/Stone statue/IMAGE0084.jpg
# Sejong/train/Stone statue/IMAGE0085.jpg
# Sejong/train/Stone statue/IMAGE0086.jpg
# Sejong/train/Stone statue/IMAGE0087.jpg
# Sejong/train/Stone statue/IMAGE0088.jpg
# Sejong/train/Stone statue/IMAGE0089.jpg
# Sejong/train/Stone statue/IMAGE0090.jpg
# Sejong/train/Stone statue/IMAGE0091.jpg
# Sejong/train/Stone statue/IMAGE0092.jpg
# Sejong/train/Stone statue/IMAGE0093.jpg
# Sejong/train/Stone statue/IMAGE0094.jpg
# Sejong/train/Stone statue/IMAGE0095.jpg
# Sejong/train/Stone statue/IMAGE0096.jpg
# Sejong/train/Stone statue/IMAGE0097.jpg
# Sejong/train/Stone statue/IMAGE0098.jpg
# Sejong/train/Stone statue/IMAGE0099.jpg
# Sejong/train/Stone statue/IMAGE0100.jpg
# Sejong/train/Stone statue/IMAGE0101.jpg
# Sejong/train/Stone statue/IMAGE0102.jpg
# Sejong/train/Stone statue/IMAGE0103.jpg
# Sejong/train/Stone statue/IMAGE0104.jpg
# Sejong/train/Stone statue/IMAGE0105.jpg
# Sejong/train/Stone statue/IMAGE0106.jpg
# Sejong/train/Stone statue/IMAGE0107.jpg

# %% [markdown]
# # **다음과 같이 정상적으로 설치 됐는지 확인합니다.**
#
# ![확인](https://user-images.githubusercontent.com/44772344/58857792-015ac400-86e1-11e9-9cd3-a4f772cfccfe.PNG)
#
#
# **다음으로는 NetVLAD와 TripletNEt을 섞은 EmbedNet을 통해서 학습을 진행할 예정입니다.**
#
# ![모델](https://user-images.githubusercontent.com/44772344/58701146-24cdf800-83dd-11e9-924d-4e5e247bfec3.png)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import tensorflow as tf

from torch.autograd import Variable
from torchvision.models import resnet18

from tensorflow import keras
from keras.preprocessing import image

import PIL
import torch
import torchvision

import matplotlib.pyplot as plt
from sklearn import svm, datasets, metrics

torch.manual_seed(777)

# %%
# !pip install tensorboardcolab
from tensorboardcolab import TensorBoardColab
tb = TensorBoardColab()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorboardcolab
#   Downloading tensorboardcolab-0.0.22.tar.gz (2.5 kB)
# Building wheels for collected packages: tensorboardcolab
#   Building wheel for tensorboardcolab (setup.py) ... done
#   Created wheel for tensorboardcolab: filename=tensorboardcolab-0.0.22-py3-none-any.whl size=3859 sha256=bc9c04557c0259fd6019cd01318a77ec750a1c18edca4d90f7dcac73ae8307d9
#   Stored in directory: /root/.cache/pip/wheels/69/4e/4a/1c6c267395cb10edded1050df12af165d3254cfce324e80941
# Successfully built tensorboardcolab
# Installing collected packages: tensorboardcolab
# Successfully installed tensorboardcolab-0.0.22
# Wait for 8 seconds...
# TensorBoard link:
# https://c10f-34-143-171-163.ngrok.io

# %% [markdown]
# ## **NetVLAD와 TripletLoss를 결합하는 코드는 다음 깃허브에서 참고했습니다.**
#
# # [바로가기](https://github.com/lyakaap/NetVLAD-pytorch)

# %%
class NetVLAD(nn.Module):
    """NetVLAD layer implementation"""

    def __init__(self, num_clusters=6, dim=128, alpha=100.0,
                 normalize_input=True):
        """
        Args:
            num_clusters : int
                The number of clusters
            dim : int
                Dimension of descriptors
            alpha : float
                Parameter of initialization. Larger value is harder assignment.
            normalize_input : bool
                If true, descriptor-wise L2 normalization is applied to input.
        """
        super(NetVLAD, self).__init__()
        self.num_clusters = num_clusters
        self.dim = dim
        self.alpha = alpha
        self.normalize_input = normalize_input
        self.conv = nn.Conv2d(dim, num_clusters, kernel_size=(1, 1), bias=True)
        self.centroids = nn.Parameter(torch.rand(num_clusters, dim))
        self._init_params()

    def _init_params(self):
        self.conv.weight = nn.Parameter(
            (2.0 * self.alpha * self.centroids).unsqueeze(-1).unsqueeze(-1)
        )
        self.conv.bias = nn.Parameter(
            - self.alpha * self.centroids.norm(dim=1)
        )

    def forward(self, x):
        N, C = x.shape[:2]

        if self.normalize_input:
            x = F.normalize(x, p=2, dim=1)  # across descriptor dim

        # soft-assignment
        soft_assign = self.conv(x).view(N, self.num_clusters, -1)
        soft_assign = F.softmax(soft_assign, dim=1)

        x_flatten = x.view(N, C, -1)
        
        # calculate residuals to each clusters
        residual = x_flatten.expand(self.num_clusters, -1, -1, -1).permute(1, 0, 2, 3) - \
            self.centroids.expand(x_flatten.size(-1), -1, -1).permute(1, 2, 0).unsqueeze(0)
        residual *= soft_assign.unsqueeze(2)
        vlad = residual.sum(dim=-1)

        vlad = F.normalize(vlad, p=2, dim=2)  # intra-normalization
        vlad = vlad.view(x.size(0), -1)  # flatten
        vlad = F.normalize(vlad, p=2, dim=1)  # L2 normalize

        return vlad

# %%
class EmbedNet(nn.Module):
    def __init__(self, base_model, net_vlad):
        super(EmbedNet, self).__init__()
        self.base_model = base_model
        self.net_vlad = net_vlad

    def forward(self, x):
        x = self.base_model(x)
        embedded_x = self.net_vlad(x)
        return embedded_x
      
class TripletNet(nn.Module):
    def __init__(self, embed_net):
        super(TripletNet, self).__init__()
        self.embed_net = embed_net

    def forward(self, a, p, n):
        embedded_a = self.embed_net(a)
        embedded_p = self.embed_net(p)
        embedded_n = self.embed_net(n)
        return embedded_a, embedded_p, embedded_n

    def feature_extract(self, x):
        return self.embed_net(x)

# %%
class HardTripletLoss(nn.Module):
    """Hard/Hardest Triplet Loss
    (pytorch implementation of https://omoindrot.github.io/triplet-loss)
    For each anchor, we get the hardest positive and hardest negative to form a triplet.
    """
    def __init__(self, margin=0.1, hardest=False, squared=False):
        """
        Args:
            margin: margin for triplet loss
            hardest: If true, loss is considered only hardest triplets.
            squared: If true, output is the pairwise squared euclidean distance matrix.
                If false, output is the pairwise euclidean distance matrix.
        """
        super(HardTripletLoss, self).__init__()
        self.margin = margin
        self.hardest = hardest
        self.squared = squared

    def forward(self, embeddings, labels):
        """
        Args:
            labels: labels of the batch, of size (batch_size,)
            embeddings: tensor of shape (batch_size, embed_dim)
        Returns:
            triplet_loss: scalar tensor containing the triplet loss
        """
        pairwise_dist = _pairwise_distance(embeddings, squared=self.squared)

        if self.hardest:
            # Get the hardest positive pairs
            mask_anchor_positive = _get_anchor_positive_triplet_mask(labels).float()
            valid_positive_dist = pairwise_dist * mask_anchor_positive
            hardest_positive_dist, _ = torch.max(valid_positive_dist, dim=1, keepdim=True)

            # Get the hardest negative pairs
            mask_anchor_negative = _get_anchor_negative_triplet_mask(labels).float()
            max_anchor_negative_dist, _ = torch.max(pairwise_dist, dim=1, keepdim=True)
            anchor_negative_dist = pairwise_dist + max_anchor_negative_dist * (
                    1.0 - mask_anchor_negative)
            hardest_negative_dist, _ = torch.min(anchor_negative_dist, dim=1, keepdim=True)

            # Combine biggest d(a, p) and smallest d(a, n) into final triplet loss
            triplet_loss = F.relu(hardest_positive_dist - hardest_negative_dist + 0.1)
            triplet_loss = torch.mean(triplet_loss)
        else:
            anc_pos_dist = pairwise_dist.unsqueeze(dim=2)
            anc_neg_dist = pairwise_dist.unsqueeze(dim=1)

            # Compute a 3D tensor of size (batch_size, batch_size, batch_size)
            # triplet_loss[i, j, k] will contain the triplet loss of anc=i, pos=j, neg=k
            # Uses broadcasting where the 1st argument has shape (batch_size, batch_size, 1)
            # and the 2nd (batch_size, 1, batch_size)
            loss = anc_pos_dist - anc_neg_dist + self.margin

            mask = _get_triplet_mask(labels).float()
            triplet_loss = loss * mask

            # Remove negative losses (i.e. the easy triplets)
            triplet_loss = F.relu(triplet_loss)

            # Count number of hard triplets (where triplet_loss > 0)
            hard_triplets = torch.gt(triplet_loss, 1e-16).float()
            num_hard_triplets = torch.sum(hard_triplets)

            triplet_loss = torch.sum(triplet_loss) / (num_hard_triplets + 1e-16)

        return triplet_loss


def _pairwise_distance(x, squared=False, eps=1e-16):
    # Compute the 2D matrix of distances between all the embeddings.

    cor_mat = torch.matmul(x, x.t())
    norm_mat = cor_mat.diag()
    distances = norm_mat.unsqueeze(1) - 2 * cor_mat + norm_mat.unsqueeze(0)
    distances = F.relu(distances)

    if not squared:
        mask = torch.eq(distances, 0.0).float()
        distances = distances + mask * eps
        distances = torch.sqrt(distances)
        distances = distances * (1.0 - mask)

    return distances


def _get_anchor_positive_triplet_mask(labels):
    # Return a 2D mask where mask[a, p] is True iff a and p are distinct and have same label.

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    indices_not_equal = torch.eye(labels.shape[0]).to(device).byte() ^ 1

    # Check if labels[i] == labels[j]
    labels_equal = torch.unsqueeze(labels, 0) == torch.unsqueeze(labels, 1)

    mask = indices_not_equal * labels_equal

    return mask


def _get_anchor_negative_triplet_mask(labels):
    # Return a 2D mask where mask[a, n] is True iff a and n have distinct labels.

    # Check if labels[i] != labels[k]
    labels_equal = torch.unsqueeze(labels, 0) == torch.unsqueeze(labels, 1)
    mask = labels_equal ^ 1

    return mask


def _get_triplet_mask(labels):
    """Return a 3D mask where mask[a, p, n] is True iff the triplet (a, p, n) is valid.
    A triplet (i, j, k) is valid if:
        - i, j, k are distinct
        - labels[i] == labels[j] and labels[i] != labels[k]
    """
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    # Check that i, j and k are distinct
    indices_not_same = torch.eye(labels.shape[0]).to(device).byte() ^ 1
    i_not_equal_j = torch.unsqueeze(indices_not_same, 2)
    i_not_equal_k = torch.unsqueeze(indices_not_same, 1)
    j_not_equal_k = torch.unsqueeze(indices_not_same, 0)
    distinct_indices = i_not_equal_j * i_not_equal_k * j_not_equal_k

    # Check if labels[i] == labels[j] and labels[i] != labels[k]
    label_equal = torch.eq(torch.unsqueeze(labels, 0), torch.unsqueeze(labels, 1))
    i_equal_j = torch.unsqueeze(label_equal, 2)
    i_equal_k = torch.unsqueeze(label_equal, 1)
    valid_labels = i_equal_j * (~i_equal_k)

    mask = distinct_indices * valid_labels   # Combine the two masks

    return mask

# %%
# Discard layers at the end of base network
encoder = resnet18(pretrained=True)
base_model = nn.Sequential(
    encoder.conv1,
    encoder.bn1,
    encoder.relu,
    encoder.maxpool,
    encoder.layer1,
    encoder.layer2,
    encoder.layer3,
    encoder.layer4,
)
dim = list(base_model.parameters())[-1].shape[0]  # last channels (512)

# Define model for embedding
net_vlad = NetVLAD(num_clusters=6, dim=dim, alpha=1.0)
model = EmbedNet(base_model, net_vlad).cuda()
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %% [markdown]
# ## 실제 학습을 진행하는 부분입니다.
# #### Epoch = ??/ batch = 8을 설정하겠습니다.

# %%
# Define loss
criterion = HardTripletLoss(margin=0.1).cuda()
epochs = 50
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# %% [markdown]
#  #### 'colab oserror errno 5 input/output error' 를 해결하기 위해
#  #### 모든 데이터를 로드해 캐시에 저장하고 이후에 학습을 진행하겠습니다.

# %%
transforms = torchvision.transforms.Compose([
    torchvision.transforms.Resize((128,128)),               
    torchvision.transforms.ToTensor()
    
])

bef_train_imagenet_data = torchvision.datasets.ImageFolder('./Sejong/train', transform=transforms)
bef_train_data_loader = torch.utils.data.DataLoader(bef_train_imagenet_data,
                                          batch_size=776,
                                          shuffle=False,
                                          num_workers=0)

# %%
for bef_train_image,bef_train_label in bef_train_data_loader :
  bef_train_image = bef_train_image
  bef_train_label = bef_train_label

# %%
train_imagenet_data = torchvision.datasets.ImageFolder('./Sejong/train', transform=transforms)
train_data_loader = torch.utils.data.DataLoader(train_imagenet_data,
                                          batch_size=8,
                                          shuffle=True,
                                          num_workers=0)
test_imagenet_data = torchvision.datasets.ImageFolder('./Sejong/test', transform=transforms)
test_data_loader = torch.utils.data.DataLoader(test_imagenet_data,
                                          shuffle=False,
                                          batch_size=100,
                                          num_workers=0)

# %%
globaliter = 0

for epoch in range(epochs):
  for batch_idx, (train_image,train_label) in enumerate(train_data_loader) :
    output_train = model(train_image.cuda())
    triplet_loss = criterion(output_train, train_label.cuda())
    optimizer.zero_grad()
    triplet_loss.backward(retain_graph=True)
    optimizer.step()
    # This is where I'm recording to Tensorboard
    #tb.save_value('Train Loss', 'train_loss', globaliter, triplet_loss.item())
    print('epoch : {}, globaliter : {}, batch_idx  : {}, triplet_loss : {}'.format(epoch,globaliter,batch_idx,triplet_loss.item()))
    globaliter += 1
  model_save_name = 'model_{:02d}.pt'.format(epoch)
  path = F"./{model_save_name}" 
  torch.save(model.state_dict(), path)
# Out:
# epoch : 0, globaliter : 0, batch_idx  : 0, triplet_loss : 0.09858343005180359
# epoch : 0, globaliter : 1, batch_idx  : 1, triplet_loss : 0.09644056111574173
# epoch : 0, globaliter : 2, batch_idx  : 2, triplet_loss : 0.09733521193265915
# epoch : 0, globaliter : 3, batch_idx  : 3, triplet_loss : 0.09892940521240234
# epoch : 0, globaliter : 4, batch_idx  : 4, triplet_loss : 0.09686298668384552
# epoch : 0, globaliter : 5, batch_idx  : 5, triplet_loss : 0.0984400287270546
# epoch : 0, globaliter : 6, batch_idx  : 6, triplet_loss : 0.10039236396551132
# epoch : 0, globaliter : 7, batch_idx  : 7, triplet_loss : 0.09513545781373978
# epoch : 0, globaliter : 8, batch_idx  : 8, triplet_loss : 0.09779974818229675
# epoch : 0, globaliter : 9, batch_idx  : 9, triplet_loss : 0.09906277060508728
# epoch : 0, globaliter : 10, batch_idx  : 10, triplet_loss : 0.09591007232666016
# epoch : 0, globaliter : 11, batch_idx  : 11, triplet_loss : 0.1004812940955162
# epoch : 0, globaliter : 12, batch_idx  : 12, triplet_loss : 0.0996931791305542
# epoch : 0, globaliter : 13, batch_idx  : 13, triplet_loss : 0.09599918127059937
# epoch : 0, globaliter : 14, batch_idx  : 14, triplet_loss : 0.09993799775838852
# epoch : 0, globaliter : 15, batch_idx  : 15, triplet_loss : 0.09759104996919632
# epoch : 0, globaliter : 16, batch_idx  : 16, triplet_loss : 0.09759337455034256
# epoch : 0, globaliter : 17, batch_idx  : 17, triplet_loss : 0.10085374116897583
# epoch : 0, globaliter : 18, batch_idx  : 18, triplet_loss : 0.09701643884181976
# epoch : 0, globaliter : 19, batch_idx  : 19, triplet_loss : 0.0916697159409523
# epoch : 0, globaliter : 20, batch_idx  : 20, triplet_loss : 0.09811913222074509
# epoch : 0, globaliter : 21, batch_idx  : 21, triplet_loss : 0.09797584265470505
# epoch : 0, globaliter : 22, batch_idx  : 22, triplet_loss : 0.09675019234418869
# epoch : 0, globaliter : 23, batch_idx  : 23, triplet_loss : 0.09896530210971832
# epoch : 0, globaliter : 24, batch_idx  : 24, triplet_loss : 0.10048972815275192
# epoch : 0, globaliter : 25, batch_idx  : 25, triplet_loss : 0.0951823964715004
# epoch : 0, globaliter : 26, batch_idx  : 26, triplet_loss : 0.09855298697948456
# epoch : 0, globaliter : 27, batch_idx  : 27, triplet_loss : 0.09084612131118774
# epoch : 0, globaliter : 28, batch_idx  : 28, triplet_loss : 0.09450968354940414
# epoch : 0, globaliter : 29, batch_idx  : 29, triplet_loss : 0.09696406126022339
# epoch : 0, globaliter : 30, batch_idx  : 30, triplet_loss : 0.09921570867300034
# epoch : 0, globaliter : 31, batch_idx  : 31, triplet_loss : 0.0991729125380516
# epoch : 0, globaliter : 32, batch_idx  : 32, triplet_loss : 0.09221569448709488
# epoch : 0, globaliter : 33, batch_idx  : 33, triplet_loss : 0.09565064311027527
# epoch : 0, globaliter : 34, batch_idx  : 34, triplet_loss : 0.09561821073293686
# epoch : 0, globaliter : 35, batch_idx  : 35, triplet_loss : 0.09458662569522858
# epoch : 0, globaliter : 36, batch_idx  : 36, triplet_loss : 0.09722355008125305
# epoch : 0, globaliter : 37, batch_idx  : 37, triplet_loss : 0.09465596079826355
# epoch : 0, globaliter : 38, batch_idx  : 38, triplet_loss : 0.08811739832162857
# epoch : 0, globaliter : 39, batch_idx  : 39, triplet_loss : 0.09351648390293121
# epoch : 0, globaliter : 40, batch_idx  : 40, triplet_loss : 0.09505356848239899
# epoch : 0, globaliter : 41, batch_idx  : 41, triplet_loss : 0.09458445757627487
# epoch : 0, globaliter : 42, batch_idx  : 42, triplet_loss : 0.09347514063119888
# epoch : 0, globaliter : 43, batch_idx  : 43, triplet_loss : 0.089387908577919
# epoch : 0, globaliter : 44, batch_idx  : 44, triplet_loss : 0.09648589789867401
# epoch : 0, globaliter : 45, batch_idx  : 45, triplet_loss : 0.09710679948329926
# epoch : 0, globaliter : 46, batch_idx  : 46, triplet_loss : 0.09171370416879654
# epoch : 0, globaliter : 47, batch_idx  : 47, triplet_loss : 0.09263647347688675
# epoch : 0, globaliter : 48, batch_idx  : 48, triplet_loss : 0.0935278832912445
# epoch : 0, globaliter : 49, batch_idx  : 49, triplet_loss : 0.09597518295049667
# epoch : 0, globaliter : 50, batch_idx  : 50, triplet_loss : 0.09576970338821411
# epoch : 0, globaliter : 51, batch_idx  : 51, triplet_loss : 0.0980323851108551
# epoch : 0, globaliter : 52, batch_idx  : 52, triplet_loss : 0.09747940301895142
# epoch : 0, globaliter : 53, batch_idx  : 53, triplet_loss : 0.08991023153066635
# epoch : 0, globaliter : 54, batch_idx  : 54, triplet_loss : 0.09698180854320526
# epoch : 0, globaliter : 55, batch_idx  : 55, triplet_loss : 0.0905074030160904
# epoch : 0, globaliter : 56, batch_idx  : 56, triplet_loss : 0.08956607431173325
# epoch : 0, globaliter : 57, batch_idx  : 57, triplet_loss : 0.09366671741008759
# epoch : 0, globaliter : 58, batch_idx  : 58, triplet_loss : 0.09461323171854019
# epoch : 0, globaliter : 59, batch_idx  : 59, triplet_loss : 0.09080136567354202
# epoch : 0, globaliter : 60, batch_idx  : 60, triplet_loss : 0.08374079316854477
# epoch : 0, globaliter : 61, batch_idx  : 61, triplet_loss : 0.09524935483932495
# epoch : 0, globaliter : 62, batch_idx  : 62, triplet_loss : 0.09508363157510757
# epoch : 0, globaliter : 63, batch_idx  : 63, triplet_loss : 0.09878287464380264
# epoch : 0, globaliter : 64, batch_idx  : 64, triplet_loss : 0.09466979652643204
# epoch : 0, globaliter : 65, batch_idx  : 65, triplet_loss : 0.09311771392822266
# epoch : 0, globaliter : 66, batch_idx  : 66, triplet_loss : 0.0911417305469513
# epoch : 0, globaliter : 67, batch_idx  : 67, triplet_loss : 0.09270254522562027
# epoch : 0, globaliter : 68, batch_idx  : 68, triplet_loss : 0.0987306758761406
# epoch : 0, globaliter : 69, batch_idx  : 69, triplet_loss : 0.09212470054626465
# epoch : 0, globaliter : 70, batch_idx  : 70, triplet_loss : 0.09168532490730286
# epoch : 0, globaliter : 71, batch_idx  : 71, triplet_loss : 0.09336725622415543
# epoch : 0, globaliter : 72, batch_idx  : 72, triplet_loss : 0.09602046012878418
# epoch : 0, globaliter : 73, batch_idx  : 73, triplet_loss : 0.09583411365747452
# epoch : 0, globaliter : 74, batch_idx  : 74, triplet_loss : 0.09391512721776962
# epoch : 0, globaliter : 75, batch_idx  : 75, triplet_loss : 0.09236522018909454
# epoch : 0, globaliter : 76, batch_idx  : 76, triplet_loss : 0.09426257014274597
# epoch : 0, globaliter : 77, batch_idx  : 77, triplet_loss : 0.09510038793087006
# epoch : 0, globaliter : 78, batch_idx  : 78, triplet_loss : 0.09426336735486984
# epoch : 0, globaliter : 79, batch_idx  : 79, triplet_loss : 0.09273472428321838
# epoch : 0, globaliter : 80, batch_idx  : 80, triplet_loss : 0.09154559671878815
# epoch : 0, globaliter : 81, batch_idx  : 81, triplet_loss : 0.09507285058498383
# epoch : 0, globaliter : 82, batch_idx  : 82, triplet_loss : 0.09414441138505936
# epoch : 0, globaliter : 83, batch_idx  : 83, triplet_loss : 0.09583871066570282
# epoch : 0, globaliter : 84, batch_idx  : 84, triplet_loss : 0.0948515385389328
# epoch : 0, globaliter : 85, batch_idx  : 85, triplet_loss : 0.09849253296852112
# epoch : 0, globaliter : 86, batch_idx  : 86, triplet_loss : 0.0893808975815773
# epoch : 0, globaliter : 87, batch_idx  : 87, triplet_loss : 0.09832829236984253
# epoch : 0, globaliter : 88, batch_idx  : 88, triplet_loss : 0.09623222053050995
# epoch : 0, globaliter : 89, batch_idx  : 89, triplet_loss : 0.09536802023649216
# epoch : 0, globaliter : 90, batch_idx  : 90, triplet_loss : 0.09672317653894424
# epoch : 0, globaliter : 91, batch_idx  : 91, triplet_loss : 0.09537074714899063
# epoch : 0, globaliter : 92, batch_idx  : 92, triplet_loss : 0.09367812424898148
# epoch : 0, globaliter : 93, batch_idx  : 93, triplet_loss : 0.09507933259010315
# epoch : 0, globaliter : 94, batch_idx  : 94, triplet_loss : 0.0884045735001564
# epoch : 0, globaliter : 95, batch_idx  : 95, triplet_loss : 0.09495222568511963
# epoch : 0, globaliter : 96, batch_idx  : 96, triplet_loss : 0.09374400973320007
# epoch : 1, globaliter : 97, batch_idx  : 0, triplet_loss : 0.09599722176790237
# epoch : 1, globaliter : 98, batch_idx  : 1, triplet_loss : 0.09490904957056046
# epoch : 1, globaliter : 99, batch_idx  : 2, triplet_loss : 0.09258347749710083
# epoch : 1, globaliter : 100, batch_idx  : 3, triplet_loss : 0.09608971327543259
# epoch : 1, globaliter : 101, batch_idx  : 4, triplet_loss : 0.08934024721384048
# epoch : 1, globaliter : 102, batch_idx  : 5, triplet_loss : 0.09737520664930344
# epoch : 1, globaliter : 103, batch_idx  : 6, triplet_loss : 0.09296128153800964
# epoch : 1, globaliter : 104, batch_idx  : 7, triplet_loss : 0.08933570235967636
# epoch : 1, globaliter : 105, batch_idx  : 8, triplet_loss : 0.09438899904489517
# epoch : 1, globaliter : 106, batch_idx  : 9, triplet_loss : 0.09205673635005951
# epoch : 1, globaliter : 107, batch_idx  : 10, triplet_loss : 0.0860605537891388
# epoch : 1, globaliter : 108, batch_idx  : 11, triplet_loss : 0.09555520117282867
# epoch : 1, globaliter : 109, batch_idx  : 12, triplet_loss : 0.0936187282204628
# epoch : 1, globaliter : 110, batch_idx  : 13, triplet_loss : 0.08918091654777527
# epoch : 1, globaliter : 111, batch_idx  : 14, triplet_loss : 0.09200383722782135
# epoch : 1, globaliter : 112, batch_idx  : 15, triplet_loss : 0.09862488508224487
# epoch : 1, globaliter : 113, batch_idx  : 16, triplet_loss : 0.0942869633436203
# epoch : 1, globaliter : 114, batch_idx  : 17, triplet_loss : 0.09591542184352875
# epoch : 1, globaliter : 115, batch_idx  : 18, triplet_loss : 0.09737435728311539
# epoch : 1, globaliter : 116, batch_idx  : 19, triplet_loss : 0.09140505641698837
# epoch : 1, globaliter : 117, batch_idx  : 20, triplet_loss : 0.09451773762702942
# epoch : 1, globaliter : 118, batch_idx  : 21, triplet_loss : 0.09594230353832245
# epoch : 1, globaliter : 119, batch_idx  : 22, triplet_loss : 0.09222570061683655
# epoch : 1, globaliter : 120, batch_idx  : 23, triplet_loss : 0.09620586037635803
# epoch : 1, globaliter : 121, batch_idx  : 24, triplet_loss : 0.09891222417354584
# epoch : 1, globaliter : 122, batch_idx  : 25, triplet_loss : 0.09578277915716171
# epoch : 1, globaliter : 123, batch_idx  : 26, triplet_loss : 0.09215517342090607
# epoch : 1, globaliter : 124, batch_idx  : 27, triplet_loss : 0.09287277609109879
# epoch : 1, globaliter : 125, batch_idx  : 28, triplet_loss : 0.09701907634735107
# epoch : 1, globaliter : 126, batch_idx  : 29, triplet_loss : 0.09696798771619797
# epoch : 1, globaliter : 127, batch_idx  : 30, triplet_loss : 0.09382370114326477
# epoch : 1, globaliter : 128, batch_idx  : 31, triplet_loss : 0.09191747009754181
# epoch : 1, globaliter : 129, batch_idx  : 32, triplet_loss : 0.09394309669733047
# epoch : 1, globaliter : 130, batch_idx  : 33, triplet_loss : 0.0931050106883049
# epoch : 1, globaliter : 131, batch_idx  : 34, triplet_loss : 0.0941433236002922
# epoch : 1, globaliter : 132, batch_idx  : 35, triplet_loss : 0.08465530723333359
# epoch : 1, globaliter : 133, batch_idx  : 36, triplet_loss : 0.08892398327589035
# epoch : 1, globaliter : 134, batch_idx  : 37, triplet_loss : 0.0918312519788742
# epoch : 1, globaliter : 135, batch_idx  : 38, triplet_loss : 0.08848059922456741
# epoch : 1, globaliter : 136, batch_idx  : 39, triplet_loss : 0.08649984747171402
# epoch : 1, globaliter : 137, batch_idx  : 40, triplet_loss : 0.0939362421631813
# epoch : 1, globaliter : 138, batch_idx  : 41, triplet_loss : 0.09881295263767242
# epoch : 1, globaliter : 139, batch_idx  : 42, triplet_loss : 0.08356155455112457
# epoch : 1, globaliter : 140, batch_idx  : 43, triplet_loss : 0.09541738033294678
# epoch : 1, globaliter : 141, batch_idx  : 44, triplet_loss : 0.09500858932733536
# epoch : 1, globaliter : 142, batch_idx  : 45, triplet_loss : 0.09363330155611038
# epoch : 1, globaliter : 143, batch_idx  : 46, triplet_loss : 0.08875765651464462
# epoch : 1, globaliter : 144, batch_idx  : 47, triplet_loss : 0.08464625477790833
# epoch : 1, globaliter : 145, batch_idx  : 48, triplet_loss : 0.09344882518053055
# epoch : 1, globaliter : 146, batch_idx  : 49, triplet_loss : 0.09749878942966461
# epoch : 1, globaliter : 147, batch_idx  : 50, triplet_loss : 0.09238161891698837
# epoch : 1, globaliter : 148, batch_idx  : 51, triplet_loss : 0.0915297418832779
# epoch : 1, globaliter : 149, batch_idx  : 52, triplet_loss : 0.09379389882087708
# epoch : 1, globaliter : 150, batch_idx  : 53, triplet_loss : 0.0952882394194603
# epoch : 1, globaliter : 151, batch_idx  : 54, triplet_loss : 0.09020229429006577
# epoch : 1, globaliter : 152, batch_idx  : 55, triplet_loss : 0.09539014101028442
# epoch : 1, globaliter : 153, batch_idx  : 56, triplet_loss : 0.09402664750814438
# epoch : 1, globaliter : 154, batch_idx  : 57, triplet_loss : 0.0922410637140274
# epoch : 1, globaliter : 155, batch_idx  : 58, triplet_loss : 0.09428414702415466
# epoch : 1, globaliter : 156, batch_idx  : 59, triplet_loss : 0.09572065621614456
# epoch : 1, globaliter : 157, batch_idx  : 60, triplet_loss : 0.09500029683113098
# epoch : 1, globaliter : 158, batch_idx  : 61, triplet_loss : 0.09679791331291199
# epoch : 1, globaliter : 159, batch_idx  : 62, triplet_loss : 0.08968757838010788
# epoch : 1, globaliter : 160, batch_idx  : 63, triplet_loss : 0.09145468473434448
# epoch : 1, globaliter : 161, batch_idx  : 64, triplet_loss : 0.08829566836357117
# epoch : 1, globaliter : 162, batch_idx  : 65, triplet_loss : 0.09144280105829239
# epoch : 1, globaliter : 163, batch_idx  : 66, triplet_loss : 0.09497559815645218
# epoch : 1, globaliter : 164, batch_idx  : 67, triplet_loss : 0.08940454572439194
# epoch : 1, globaliter : 165, batch_idx  : 68, triplet_loss : 0.08519884198904037
# epoch : 1, globaliter : 166, batch_idx  : 69, triplet_loss : 0.09301401674747467
# epoch : 1, globaliter : 167, batch_idx  : 70, triplet_loss : 0.08987444639205933
# epoch : 1, globaliter : 168, batch_idx  : 71, triplet_loss : 0.09094960242509842
# epoch : 1, globaliter : 169, batch_idx  : 72, triplet_loss : 0.09475614130496979
# epoch : 1, globaliter : 170, batch_idx  : 73, triplet_loss : 0.09172132611274719
# epoch : 1, globaliter : 171, batch_idx  : 74, triplet_loss : 0.09900525957345963
# epoch : 1, globaliter : 172, batch_idx  : 75, triplet_loss : 0.08926783502101898
# epoch : 1, globaliter : 173, batch_idx  : 76, triplet_loss : 0.0858406275510788
# epoch : 1, globaliter : 174, batch_idx  : 77, triplet_loss : 0.09607940167188644
# epoch : 1, globaliter : 175, batch_idx  : 78, triplet_loss : 0.0969814658164978
# epoch : 1, globaliter : 176, batch_idx  : 79, triplet_loss : 0.07841704040765762
# epoch : 1, globaliter : 177, batch_idx  : 80, triplet_loss : 0.08697803318500519
# epoch : 1, globaliter : 178, batch_idx  : 81, triplet_loss : 0.09240389615297318
# epoch : 1, globaliter : 179, batch_idx  : 82, triplet_loss : 0.08807056397199631
# epoch : 1, globaliter : 180, batch_idx  : 83, triplet_loss : 0.09001355618238449
# epoch : 1, globaliter : 181, batch_idx  : 84, triplet_loss : 0.09184595942497253
# epoch : 1, globaliter : 182, batch_idx  : 85, triplet_loss : 0.09028171002864838
# epoch : 1, globaliter : 183, batch_idx  : 86, triplet_loss : 0.08322269469499588
# epoch : 1, globaliter : 184, batch_idx  : 87, triplet_loss : 0.09095130860805511
# epoch : 1, globaliter : 185, batch_idx  : 88, triplet_loss : 0.06955895572900772
# epoch : 1, globaliter : 186, batch_idx  : 89, triplet_loss : 0.08504033833742142
# epoch : 1, globaliter : 187, batch_idx  : 90, triplet_loss : 0.09042497724294662
# epoch : 1, globaliter : 188, batch_idx  : 91, triplet_loss : 0.09095608443021774
# epoch : 1, globaliter : 189, batch_idx  : 92, triplet_loss : 0.09009605646133423
# epoch : 1, globaliter : 190, batch_idx  : 93, triplet_loss : 0.09274451434612274
# epoch : 1, globaliter : 191, batch_idx  : 94, triplet_loss : 0.08782915025949478
# epoch : 1, globaliter : 192, batch_idx  : 95, triplet_loss : 0.08389368653297424
# epoch : 1, globaliter : 193, batch_idx  : 96, triplet_loss : 0.08618200570344925
# epoch : 2, globaliter : 194, batch_idx  : 0, triplet_loss : 0.0916004553437233
# epoch : 2, globaliter : 195, batch_idx  : 1, triplet_loss : 0.09406591951847076
# epoch : 2, globaliter : 196, batch_idx  : 2, triplet_loss : 0.08261169493198395
# epoch : 2, globaliter : 197, batch_idx  : 3, triplet_loss : 0.08303693681955338
# epoch : 2, globaliter : 198, batch_idx  : 4, triplet_loss : 0.09289579093456268
# epoch : 2, globaliter : 199, batch_idx  : 5, triplet_loss : 0.08411162346601486
# epoch : 2, globaliter : 200, batch_idx  : 6, triplet_loss : 0.09450288861989975
# epoch : 2, globaliter : 201, batch_idx  : 7, triplet_loss : 0.08938708156347275
# epoch : 2, globaliter : 202, batch_idx  : 8, triplet_loss : 0.09241890907287598
# epoch : 2, globaliter : 203, batch_idx  : 9, triplet_loss : 0.09037574380636215
# epoch : 2, globaliter : 204, batch_idx  : 10, triplet_loss : 0.09714344143867493
# epoch : 2, globaliter : 205, batch_idx  : 11, triplet_loss : 0.07207969576120377
# epoch : 2, globaliter : 206, batch_idx  : 12, triplet_loss : 0.08682996034622192
# epoch : 2, globaliter : 207, batch_idx  : 13, triplet_loss : 0.08413369208574295
# epoch : 2, globaliter : 208, batch_idx  : 14, triplet_loss : 0.08078701794147491
# epoch : 2, globaliter : 209, batch_idx  : 15, triplet_loss : 0.08292976766824722
# epoch : 2, globaliter : 210, batch_idx  : 16, triplet_loss : 0.09097298234701157
# epoch : 2, globaliter : 211, batch_idx  : 17, triplet_loss : 0.08986879140138626
# epoch : 2, globaliter : 212, batch_idx  : 18, triplet_loss : 0.08904463797807693
# epoch : 2, globaliter : 213, batch_idx  : 19, triplet_loss : 0.0830199345946312
# epoch : 2, globaliter : 214, batch_idx  : 20, triplet_loss : 0.08163891732692719
# epoch : 2, globaliter : 215, batch_idx  : 21, triplet_loss : 0.092640720307827
# epoch : 2, globaliter : 216, batch_idx  : 22, triplet_loss : 0.09134122729301453
# epoch : 2, globaliter : 217, batch_idx  : 23, triplet_loss : 0.09558223932981491
# epoch : 2, globaliter : 218, batch_idx  : 24, triplet_loss : 0.07763446122407913
# epoch : 2, globaliter : 219, batch_idx  : 25, triplet_loss : 0.08772733062505722
# epoch : 2, globaliter : 220, batch_idx  : 26, triplet_loss : 0.08570549637079239
# epoch : 2, globaliter : 221, batch_idx  : 27, triplet_loss : 0.08785779029130936
# epoch : 2, globaliter : 222, batch_idx  : 28, triplet_loss : 0.09055759012699127
# epoch : 2, globaliter : 223, batch_idx  : 29, triplet_loss : 0.08596810698509216
# epoch : 2, globaliter : 224, batch_idx  : 30, triplet_loss : 0.08811692893505096
# epoch : 2, globaliter : 225, batch_idx  : 31, triplet_loss : 0.09026452153921127
# epoch : 2, globaliter : 226, batch_idx  : 32, triplet_loss : 0.08340673893690109
# epoch : 2, globaliter : 227, batch_idx  : 33, triplet_loss : 0.0749402865767479
# epoch : 2, globaliter : 228, batch_idx  : 34, triplet_loss : 0.08663854002952576
# epoch : 2, globaliter : 229, batch_idx  : 35, triplet_loss : 0.08946442604064941
# epoch : 2, globaliter : 230, batch_idx  : 36, triplet_loss : 0.09093275666236877
# epoch : 2, globaliter : 231, batch_idx  : 37, triplet_loss : 0.09090438485145569
# epoch : 2, globaliter : 232, batch_idx  : 38, triplet_loss : 0.0890979990363121
# epoch : 2, globaliter : 233, batch_idx  : 39, triplet_loss : 0.08061444014310837
# epoch : 2, globaliter : 234, batch_idx  : 40, triplet_loss : 0.09629615396261215
# epoch : 2, globaliter : 235, batch_idx  : 41, triplet_loss : 0.09370648860931396
# epoch : 2, globaliter : 236, batch_idx  : 42, triplet_loss : 0.09014972299337387
# epoch : 2, globaliter : 237, batch_idx  : 43, triplet_loss : 0.08236683905124664
# epoch : 2, globaliter : 238, batch_idx  : 44, triplet_loss : 0.07741918414831161
# epoch : 2, globaliter : 239, batch_idx  : 45, triplet_loss : 0.08577597886323929
# epoch : 2, globaliter : 240, batch_idx  : 46, triplet_loss : 0.0860438346862793
# epoch : 2, globaliter : 241, batch_idx  : 47, triplet_loss : 0.08810634166002274
# epoch : 2, globaliter : 242, batch_idx  : 48, triplet_loss : 0.08647648245096207
# epoch : 2, globaliter : 243, batch_idx  : 49, triplet_loss : 0.0821320116519928
# epoch : 2, globaliter : 244, batch_idx  : 50, triplet_loss : 0.0744994655251503
# epoch : 2, globaliter : 245, batch_idx  : 51, triplet_loss : 0.08813151717185974
# epoch : 2, globaliter : 246, batch_idx  : 52, triplet_loss : 0.09326678514480591
# epoch : 2, globaliter : 247, batch_idx  : 53, triplet_loss : 0.08460278809070587
# epoch : 2, globaliter : 248, batch_idx  : 54, triplet_loss : 0.07054726034402847
# epoch : 2, globaliter : 249, batch_idx  : 55, triplet_loss : 0.08263429254293442
# epoch : 2, globaliter : 250, batch_idx  : 56, triplet_loss : 0.08588436990976334
# epoch : 2, globaliter : 251, batch_idx  : 57, triplet_loss : 0.07626713067293167
# epoch : 2, globaliter : 252, batch_idx  : 58, triplet_loss : 0.08858449012041092
# epoch : 2, globaliter : 253, batch_idx  : 59, triplet_loss : 0.08173634111881256
# epoch : 2, globaliter : 254, batch_idx  : 60, triplet_loss : 0.07391507178544998
# epoch : 2, globaliter : 255, batch_idx  : 61, triplet_loss : 0.06911489367485046
# epoch : 2, globaliter : 256, batch_idx  : 62, triplet_loss : 0.08119284361600876
# epoch : 2, globaliter : 257, batch_idx  : 63, triplet_loss : 0.08858896046876907
# epoch : 2, globaliter : 258, batch_idx  : 64, triplet_loss : 0.07946542650461197
# epoch : 2, globaliter : 259, batch_idx  : 65, triplet_loss : 0.08520924299955368
# epoch : 2, globaliter : 260, batch_idx  : 66, triplet_loss : 0.07719764113426208
# epoch : 2, globaliter : 261, batch_idx  : 67, triplet_loss : 0.08041509240865707
# epoch : 2, globaliter : 262, batch_idx  : 68, triplet_loss : 0.08134238421916962
# epoch : 2, globaliter : 263, batch_idx  : 69, triplet_loss : 0.08194205164909363
# epoch : 2, globaliter : 264, batch_idx  : 70, triplet_loss : 0.08984234929084778
# epoch : 2, globaliter : 265, batch_idx  : 71, triplet_loss : 0.08040668070316315
# epoch : 2, globaliter : 266, batch_idx  : 72, triplet_loss : 0.08822253346443176
# epoch : 2, globaliter : 267, batch_idx  : 73, triplet_loss : 0.09026964008808136
# epoch : 2, globaliter : 268, batch_idx  : 74, triplet_loss : 0.08705760538578033
# epoch : 2, globaliter : 269, batch_idx  : 75, triplet_loss : 0.09068381786346436
# epoch : 2, globaliter : 270, batch_idx  : 76, triplet_loss : 0.08400747179985046
# epoch : 2, globaliter : 271, batch_idx  : 77, triplet_loss : 0.09027218818664551
# epoch : 2, globaliter : 272, batch_idx  : 78, triplet_loss : 0.08514030277729034
# epoch : 2, globaliter : 273, batch_idx  : 79, triplet_loss : 0.08930518478155136
# epoch : 2, globaliter : 274, batch_idx  : 80, triplet_loss : 0.08930511772632599
# epoch : 2, globaliter : 275, batch_idx  : 81, triplet_loss : 0.08000481128692627
# epoch : 2, globaliter : 276, batch_idx  : 82, triplet_loss : 0.08983591943979263
# epoch : 2, globaliter : 277, batch_idx  : 83, triplet_loss : 0.07342343777418137
# epoch : 2, globaliter : 278, batch_idx  : 84, triplet_loss : 0.07842474430799484
# epoch : 2, globaliter : 279, batch_idx  : 85, triplet_loss : 0.08517792075872421
# epoch : 2, globaliter : 280, batch_idx  : 86, triplet_loss : 0.07699332386255264
# epoch : 2, globaliter : 281, batch_idx  : 87, triplet_loss : 0.08101748675107956
# epoch : 2, globaliter : 282, batch_idx  : 88, triplet_loss : 0.0841536819934845
# epoch : 2, globaliter : 283, batch_idx  : 89, triplet_loss : 0.06564458459615707
# epoch : 2, globaliter : 284, batch_idx  : 90, triplet_loss : 0.09256362169981003
# epoch : 2, globaliter : 285, batch_idx  : 91, triplet_loss : 0.09337059408426285
# epoch : 2, globaliter : 286, batch_idx  : 92, triplet_loss : 0.09784518927335739
# epoch : 2, globaliter : 287, batch_idx  : 93, triplet_loss : 0.07645569741725922
# epoch : 2, globaliter : 288, batch_idx  : 94, triplet_loss : 0.09281440824270248
# epoch : 2, globaliter : 289, batch_idx  : 95, triplet_loss : 0.08555532246828079
# epoch : 2, globaliter : 290, batch_idx  : 96, triplet_loss : 0.07516539841890335
# epoch : 3, globaliter : 291, batch_idx  : 0, triplet_loss : 0.08225282281637192
# epoch : 3, globaliter : 292, batch_idx  : 1, triplet_loss : 0.08839186280965805
# epoch : 3, globaliter : 293, batch_idx  : 2, triplet_loss : 0.07664760202169418
# epoch : 3, globaliter : 294, batch_idx  : 3, triplet_loss : 0.08062658458948135
# epoch : 3, globaliter : 295, batch_idx  : 4, triplet_loss : 0.07741174846887589
# epoch : 3, globaliter : 296, batch_idx  : 5, triplet_loss : 0.07547183334827423
# epoch : 3, globaliter : 297, batch_idx  : 6, triplet_loss : 0.08233781158924103
# epoch : 3, globaliter : 298, batch_idx  : 7, triplet_loss : 0.06849338114261627
# epoch : 3, globaliter : 299, batch_idx  : 8, triplet_loss : 0.0761108249425888
# epoch : 3, globaliter : 300, batch_idx  : 9, triplet_loss : 0.08934793621301651
# epoch : 3, globaliter : 301, batch_idx  : 10, triplet_loss : 0.0879472866654396
# epoch : 3, globaliter : 302, batch_idx  : 11, triplet_loss : 0.08663800358772278
# epoch : 3, globaliter : 303, batch_idx  : 12, triplet_loss : 0.08225379884243011
# epoch : 3, globaliter : 304, batch_idx  : 13, triplet_loss : 0.07564476877450943
# epoch : 3, globaliter : 305, batch_idx  : 14, triplet_loss : 0.08255045861005783
# epoch : 3, globaliter : 306, batch_idx  : 15, triplet_loss : 0.08542189002037048
# epoch : 3, globaliter : 307, batch_idx  : 16, triplet_loss : 0.07762917131185532
# epoch : 3, globaliter : 308, batch_idx  : 17, triplet_loss : 0.07092513889074326
# epoch : 3, globaliter : 309, batch_idx  : 18, triplet_loss : 0.06521213054656982
# epoch : 3, globaliter : 310, batch_idx  : 19, triplet_loss : 0.06967224180698395
# epoch : 3, globaliter : 311, batch_idx  : 20, triplet_loss : 0.07760213315486908
# epoch : 3, globaliter : 312, batch_idx  : 21, triplet_loss : 0.08395359665155411
# epoch : 3, globaliter : 313, batch_idx  : 22, triplet_loss : 0.06466657668352127
# epoch : 3, globaliter : 314, batch_idx  : 23, triplet_loss : 0.07592329382896423
# epoch : 3, globaliter : 315, batch_idx  : 24, triplet_loss : 0.08578301966190338
# epoch : 3, globaliter : 316, batch_idx  : 25, triplet_loss : 0.07207240164279938
# epoch : 3, globaliter : 317, batch_idx  : 26, triplet_loss : 0.07835446298122406
# epoch : 3, globaliter : 318, batch_idx  : 27, triplet_loss : 0.0811476856470108
# epoch : 3, globaliter : 319, batch_idx  : 28, triplet_loss : 0.0791049674153328
# epoch : 3, globaliter : 320, batch_idx  : 29, triplet_loss : 0.06077508255839348
# epoch : 3, globaliter : 321, batch_idx  : 30, triplet_loss : 0.07074405252933502
# epoch : 3, globaliter : 322, batch_idx  : 31, triplet_loss : 0.06191525235772133
# epoch : 3, globaliter : 323, batch_idx  : 32, triplet_loss : 0.07250795513391495
# epoch : 3, globaliter : 324, batch_idx  : 33, triplet_loss : 0.08913017809391022
# epoch : 3, globaliter : 325, batch_idx  : 34, triplet_loss : 0.07072296738624573
# epoch : 3, globaliter : 326, batch_idx  : 35, triplet_loss : 0.08620976656675339
# epoch : 3, globaliter : 327, batch_idx  : 36, triplet_loss : 0.07894180715084076
# epoch : 3, globaliter : 328, batch_idx  : 37, triplet_loss : 0.0730702355504036
# epoch : 3, globaliter : 329, batch_idx  : 38, triplet_loss : 0.07476306706666946
# epoch : 3, globaliter : 330, batch_idx  : 39, triplet_loss : 0.07163538038730621
# epoch : 3, globaliter : 331, batch_idx  : 40, triplet_loss : 0.06677767634391785
# epoch : 3, globaliter : 332, batch_idx  : 41, triplet_loss : 0.08440422266721725
# epoch : 3, globaliter : 333, batch_idx  : 42, triplet_loss : 0.08528923243284225
# epoch : 3, globaliter : 334, batch_idx  : 43, triplet_loss : 0.08735895156860352
# epoch : 3, globaliter : 335, batch_idx  : 44, triplet_loss : 0.07621219009160995
# epoch : 3, globaliter : 336, batch_idx  : 45, triplet_loss : 0.08441619575023651
# epoch : 3, globaliter : 337, batch_idx  : 46, triplet_loss : 0.07961045950651169
# epoch : 3, globaliter : 338, batch_idx  : 47, triplet_loss : 0.07819675654172897
# epoch : 3, globaliter : 339, batch_idx  : 48, triplet_loss : 0.06938346475362778
# epoch : 3, globaliter : 340, batch_idx  : 49, triplet_loss : 0.07985247671604156
# epoch : 3, globaliter : 341, batch_idx  : 50, triplet_loss : 0.07018841803073883
# epoch : 3, globaliter : 342, batch_idx  : 51, triplet_loss : 0.07394502311944962
# epoch : 3, globaliter : 343, batch_idx  : 52, triplet_loss : 0.08827737718820572
# epoch : 3, globaliter : 344, batch_idx  : 53, triplet_loss : 0.08780492097139359
# epoch : 3, globaliter : 345, batch_idx  : 54, triplet_loss : 0.07248026132583618
# epoch : 3, globaliter : 346, batch_idx  : 55, triplet_loss : 0.07127641886472702
# epoch : 3, globaliter : 347, batch_idx  : 56, triplet_loss : 0.09646257758140564
# epoch : 3, globaliter : 348, batch_idx  : 57, triplet_loss : 0.07634170353412628
# epoch : 3, globaliter : 349, batch_idx  : 58, triplet_loss : 0.0762348622083664
# epoch : 3, globaliter : 350, batch_idx  : 59, triplet_loss : 0.06899711489677429
# epoch : 3, globaliter : 351, batch_idx  : 60, triplet_loss : 0.08803960680961609
# epoch : 3, globaliter : 352, batch_idx  : 61, triplet_loss : 0.07128642499446869
# epoch : 3, globaliter : 353, batch_idx  : 62, triplet_loss : 0.07282428443431854
# epoch : 3, globaliter : 354, batch_idx  : 63, triplet_loss : 0.06627093255519867
# epoch : 3, globaliter : 355, batch_idx  : 64, triplet_loss : 0.09151314944028854
# epoch : 3, globaliter : 356, batch_idx  : 65, triplet_loss : 0.07917607575654984
# epoch : 3, globaliter : 357, batch_idx  : 66, triplet_loss : 0.0676816925406456
# epoch : 3, globaliter : 358, batch_idx  : 67, triplet_loss : 0.082634836435318
# epoch : 3, globaliter : 359, batch_idx  : 68, triplet_loss : 0.07969929277896881
# epoch : 3, globaliter : 360, batch_idx  : 69, triplet_loss : 0.07024271041154861
# epoch : 3, globaliter : 361, batch_idx  : 70, triplet_loss : 0.0816420242190361
# epoch : 3, globaliter : 362, batch_idx  : 71, triplet_loss : 0.07762563973665237
# epoch : 3, globaliter : 363, batch_idx  : 72, triplet_loss : 0.04987630248069763
# epoch : 3, globaliter : 364, batch_idx  : 73, triplet_loss : 0.05527674779295921
# epoch : 3, globaliter : 365, batch_idx  : 74, triplet_loss : 0.06981170177459717
# epoch : 3, globaliter : 366, batch_idx  : 75, triplet_loss : 0.08279485255479813
# epoch : 3, globaliter : 367, batch_idx  : 76, triplet_loss : 0.050926435738801956
# epoch : 3, globaliter : 368, batch_idx  : 77, triplet_loss : 0.06496666371822357
# epoch : 3, globaliter : 369, batch_idx  : 78, triplet_loss : 0.06603948026895523
# epoch : 3, globaliter : 370, batch_idx  : 79, triplet_loss : 0.07870359718799591
# epoch : 3, globaliter : 371, batch_idx  : 80, triplet_loss : 0.07243133336305618
# epoch : 3, globaliter : 372, batch_idx  : 81, triplet_loss : 0.073813296854496
# epoch : 3, globaliter : 373, batch_idx  : 82, triplet_loss : 0.07228866964578629
# epoch : 3, globaliter : 374, batch_idx  : 83, triplet_loss : 0.06783639639616013
# epoch : 3, globaliter : 375, batch_idx  : 84, triplet_loss : 0.0757777988910675
# epoch : 3, globaliter : 376, batch_idx  : 85, triplet_loss : 0.06318226456642151
# epoch : 3, globaliter : 377, batch_idx  : 86, triplet_loss : 0.057091694325208664
# epoch : 3, globaliter : 378, batch_idx  : 87, triplet_loss : 0.07633093744516373
# epoch : 3, globaliter : 379, batch_idx  : 88, triplet_loss : 0.06677502393722534
# epoch : 3, globaliter : 380, batch_idx  : 89, triplet_loss : 0.06851504743099213
# epoch : 3, globaliter : 381, batch_idx  : 90, triplet_loss : 0.07232413440942764
# epoch : 3, globaliter : 382, batch_idx  : 91, triplet_loss : 0.08878222852945328
# epoch : 3, globaliter : 383, batch_idx  : 92, triplet_loss : 0.07775617390871048
# epoch : 3, globaliter : 384, batch_idx  : 93, triplet_loss : 0.0786542296409607
# epoch : 3, globaliter : 385, batch_idx  : 94, triplet_loss : 0.07708729803562164
# epoch : 3, globaliter : 386, batch_idx  : 95, triplet_loss : 0.07232271134853363
# epoch : 3, globaliter : 387, batch_idx  : 96, triplet_loss : 0.0631222352385521
# epoch : 4, globaliter : 388, batch_idx  : 0, triplet_loss : 0.06729148328304291
# epoch : 4, globaliter : 389, batch_idx  : 1, triplet_loss : 0.08867158740758896
# epoch : 4, globaliter : 390, batch_idx  : 2, triplet_loss : 0.05112845078110695
# epoch : 4, globaliter : 391, batch_idx  : 3, triplet_loss : 0.07587368041276932
# epoch : 4, globaliter : 392, batch_idx  : 4, triplet_loss : 0.06521192938089371
# epoch : 4, globaliter : 393, batch_idx  : 5, triplet_loss : 0.05928453803062439
# epoch : 4, globaliter : 394, batch_idx  : 6, triplet_loss : 0.076534204185009
# epoch : 4, globaliter : 395, batch_idx  : 7, triplet_loss : 0.07152193039655685
# epoch : 4, globaliter : 396, batch_idx  : 8, triplet_loss : 0.06403625756502151
# epoch : 4, globaliter : 397, batch_idx  : 9, triplet_loss : 0.07240214198827744
# epoch : 4, globaliter : 398, batch_idx  : 10, triplet_loss : 0.0783119723200798
# epoch : 4, globaliter : 399, batch_idx  : 11, triplet_loss : 0.08278243988752365
# epoch : 4, globaliter : 400, batch_idx  : 12, triplet_loss : 0.07574208825826645
# epoch : 4, globaliter : 401, batch_idx  : 13, triplet_loss : 0.06826596707105637
# epoch : 4, globaliter : 402, batch_idx  : 14, triplet_loss : 0.06232938542962074
# epoch : 4, globaliter : 403, batch_idx  : 15, triplet_loss : 0.06990475207567215
# epoch : 4, globaliter : 404, batch_idx  : 16, triplet_loss : 0.06288806349039078
# epoch : 4, globaliter : 405, batch_idx  : 17, triplet_loss : 0.07285162061452866
# epoch : 4, globaliter : 406, batch_idx  : 18, triplet_loss : 0.05959954857826233
# epoch : 4, globaliter : 407, batch_idx  : 19, triplet_loss : 0.0855974480509758
# epoch : 4, globaliter : 408, batch_idx  : 20, triplet_loss : 0.05779166892170906
# epoch : 4, globaliter : 409, batch_idx  : 21, triplet_loss : 0.05041046440601349
# epoch : 4, globaliter : 410, batch_idx  : 22, triplet_loss : 0.07450510561466217
# epoch : 4, globaliter : 411, batch_idx  : 23, triplet_loss : 0.044808998703956604
# epoch : 4, globaliter : 412, batch_idx  : 24, triplet_loss : 0.0565415695309639
# epoch : 4, globaliter : 413, batch_idx  : 25, triplet_loss : 0.08205845952033997
# epoch : 4, globaliter : 414, batch_idx  : 26, triplet_loss : 0.06927792727947235
# epoch : 4, globaliter : 415, batch_idx  : 27, triplet_loss : 0.06704016029834747
# epoch : 4, globaliter : 416, batch_idx  : 28, triplet_loss : 0.0629325583577156
# epoch : 4, globaliter : 417, batch_idx  : 29, triplet_loss : 0.06405879557132721
# epoch : 4, globaliter : 418, batch_idx  : 30, triplet_loss : 0.0673319473862648
# epoch : 4, globaliter : 419, batch_idx  : 31, triplet_loss : 0.08069054037332535
# epoch : 4, globaliter : 420, batch_idx  : 32, triplet_loss : 0.044114742428064346
# epoch : 4, globaliter : 421, batch_idx  : 33, triplet_loss : 0.06234050542116165
# epoch : 4, globaliter : 422, batch_idx  : 34, triplet_loss : 0.07353886216878891
# epoch : 4, globaliter : 423, batch_idx  : 35, triplet_loss : 0.06000196561217308
# epoch : 4, globaliter : 424, batch_idx  : 36, triplet_loss : 0.041596148163080215
# epoch : 4, globaliter : 425, batch_idx  : 37, triplet_loss : 0.0589374378323555
# epoch : 4, globaliter : 426, batch_idx  : 38, triplet_loss : 0.0875566229224205
# epoch : 4, globaliter : 427, batch_idx  : 39, triplet_loss : 0.07542717456817627
# epoch : 4, globaliter : 428, batch_idx  : 40, triplet_loss : 0.07844821363687515
# epoch : 4, globaliter : 429, batch_idx  : 41, triplet_loss : 0.05025235936045647
# epoch : 4, globaliter : 430, batch_idx  : 42, triplet_loss : 0.0702819973230362
# epoch : 4, globaliter : 431, batch_idx  : 43, triplet_loss : 0.08772486448287964
# epoch : 4, globaliter : 432, batch_idx  : 44, triplet_loss : 0.07063286006450653
# epoch : 4, globaliter : 433, batch_idx  : 45, triplet_loss : 0.07616989314556122
# epoch : 4, globaliter : 434, batch_idx  : 46, triplet_loss : 0.05845661461353302
# epoch : 4, globaliter : 435, batch_idx  : 47, triplet_loss : 0.05367583781480789
# epoch : 4, globaliter : 436, batch_idx  : 48, triplet_loss : 0.08202675729990005
# epoch : 4, globaliter : 437, batch_idx  : 49, triplet_loss : 0.05334019288420677
# epoch : 4, globaliter : 438, batch_idx  : 50, triplet_loss : 0.07620178163051605
# epoch : 4, globaliter : 439, batch_idx  : 51, triplet_loss : 0.06590050458908081
# epoch : 4, globaliter : 440, batch_idx  : 52, triplet_loss : 0.07233473658561707
# epoch : 4, globaliter : 441, batch_idx  : 53, triplet_loss : 0.07437130063772202
# epoch : 4, globaliter : 442, batch_idx  : 54, triplet_loss : 0.05991784855723381
# epoch : 4, globaliter : 443, batch_idx  : 55, triplet_loss : 0.0821838304400444
# epoch : 4, globaliter : 444, batch_idx  : 56, triplet_loss : 0.06537400931119919
# epoch : 4, globaliter : 445, batch_idx  : 57, triplet_loss : 0.05945081263780594
# epoch : 4, globaliter : 446, batch_idx  : 58, triplet_loss : 0.07513660192489624
# epoch : 4, globaliter : 447, batch_idx  : 59, triplet_loss : 0.06922755390405655
# epoch : 4, globaliter : 448, batch_idx  : 60, triplet_loss : 0.05611115321516991
# epoch : 4, globaliter : 449, batch_idx  : 61, triplet_loss : 0.08250526338815689
# epoch : 4, globaliter : 450, batch_idx  : 62, triplet_loss : 0.06381021440029144
# epoch : 4, globaliter : 451, batch_idx  : 63, triplet_loss : 0.0550796203315258
# epoch : 4, globaliter : 452, batch_idx  : 64, triplet_loss : 0.06872830539941788
# epoch : 4, globaliter : 453, batch_idx  : 65, triplet_loss : 0.039194222539663315
# epoch : 4, globaliter : 454, batch_idx  : 66, triplet_loss : 0.03808644041419029
# epoch : 4, globaliter : 455, batch_idx  : 67, triplet_loss : 0.05085732415318489
# epoch : 4, globaliter : 456, batch_idx  : 68, triplet_loss : 0.07868162542581558
# epoch : 4, globaliter : 457, batch_idx  : 69, triplet_loss : 0.06952734291553497
# epoch : 4, globaliter : 458, batch_idx  : 70, triplet_loss : 0.08572287857532501
# epoch : 4, globaliter : 459, batch_idx  : 71, triplet_loss : 0.0558900348842144
# epoch : 4, globaliter : 460, batch_idx  : 72, triplet_loss : 0.060492221266031265
# epoch : 4, globaliter : 461, batch_idx  : 73, triplet_loss : 0.07134857028722763
# epoch : 4, globaliter : 462, batch_idx  : 74, triplet_loss : 0.06470950692892075
# epoch : 4, globaliter : 463, batch_idx  : 75, triplet_loss : 0.0479184165596962
# epoch : 4, globaliter : 464, batch_idx  : 76, triplet_loss : 0.055554140359163284
# epoch : 4, globaliter : 465, batch_idx  : 77, triplet_loss : 0.06554681807756424
# epoch : 4, globaliter : 466, batch_idx  : 78, triplet_loss : 0.04743049666285515
# epoch : 4, globaliter : 467, batch_idx  : 79, triplet_loss : 0.06132059171795845
# epoch : 4, globaliter : 468, batch_idx  : 80, triplet_loss : 0.06656762212514877
# epoch : 4, globaliter : 469, batch_idx  : 81, triplet_loss : 0.06308826059103012
# epoch : 4, globaliter : 470, batch_idx  : 82, triplet_loss : 0.05996258929371834
# epoch : 4, globaliter : 471, batch_idx  : 83, triplet_loss : 0.058291856199502945
# epoch : 4, globaliter : 472, batch_idx  : 84, triplet_loss : 0.04988311976194382
# epoch : 4, globaliter : 473, batch_idx  : 85, triplet_loss : 0.08231879770755768
# epoch : 4, globaliter : 474, batch_idx  : 86, triplet_loss : 0.057496827095746994
# epoch : 4, globaliter : 475, batch_idx  : 87, triplet_loss : 0.059801552444696426
# epoch : 4, globaliter : 476, batch_idx  : 88, triplet_loss : 0.05239987373352051
# epoch : 4, globaliter : 477, batch_idx  : 89, triplet_loss : 0.07678590714931488
# epoch : 4, globaliter : 478, batch_idx  : 90, triplet_loss : 0.05659344792366028
# epoch : 4, globaliter : 479, batch_idx  : 91, triplet_loss : 0.0661047026515007
# epoch : 4, globaliter : 480, batch_idx  : 92, triplet_loss : 0.06399209052324295
# epoch : 4, globaliter : 481, batch_idx  : 93, triplet_loss : 0.0699789822101593
# epoch : 4, globaliter : 482, batch_idx  : 94, triplet_loss : 0.06520462036132812
# epoch : 4, globaliter : 483, batch_idx  : 95, triplet_loss : 0.056645385921001434
# epoch : 4, globaliter : 484, batch_idx  : 96, triplet_loss : 0.061796754598617554
# epoch : 5, globaliter : 485, batch_idx  : 0, triplet_loss : 0.06580781936645508
# epoch : 5, globaliter : 486, batch_idx  : 1, triplet_loss : 0.060476381331682205
# epoch : 5, globaliter : 487, batch_idx  : 2, triplet_loss : 0.08674483746290207
# epoch : 5, globaliter : 488, batch_idx  : 3, triplet_loss : 0.0779467523097992
# epoch : 5, globaliter : 489, batch_idx  : 4, triplet_loss : 0.06637738645076752
# epoch : 5, globaliter : 490, batch_idx  : 5, triplet_loss : 0.04441080242395401
# epoch : 5, globaliter : 491, batch_idx  : 6, triplet_loss : 0.06205357238650322
# epoch : 5, globaliter : 492, batch_idx  : 7, triplet_loss : 0.07107659429311752
# epoch : 5, globaliter : 493, batch_idx  : 8, triplet_loss : 0.060282737016677856
# epoch : 5, globaliter : 494, batch_idx  : 9, triplet_loss : 0.06523357331752777
# epoch : 5, globaliter : 495, batch_idx  : 10, triplet_loss : 0.059985995292663574
# epoch : 5, globaliter : 496, batch_idx  : 11, triplet_loss : 0.06884358078241348
# epoch : 5, globaliter : 497, batch_idx  : 12, triplet_loss : 0.052692729979753494
# epoch : 5, globaliter : 498, batch_idx  : 13, triplet_loss : 0.049032799899578094
# epoch : 5, globaliter : 499, batch_idx  : 14, triplet_loss : 0.04980327934026718
# epoch : 5, globaliter : 500, batch_idx  : 15, triplet_loss : 0.0730597972869873
# epoch : 5, globaliter : 501, batch_idx  : 16, triplet_loss : 0.053833555430173874
# epoch : 5, globaliter : 502, batch_idx  : 17, triplet_loss : 0.06198505684733391
# epoch : 5, globaliter : 503, batch_idx  : 18, triplet_loss : 0.04085986688733101
# epoch : 5, globaliter : 504, batch_idx  : 19, triplet_loss : 0.04640110209584236
# epoch : 5, globaliter : 505, batch_idx  : 20, triplet_loss : 0.058107685297727585
# epoch : 5, globaliter : 506, batch_idx  : 21, triplet_loss : 0.0698818489909172
# epoch : 5, globaliter : 507, batch_idx  : 22, triplet_loss : 0.056635625660419464
# epoch : 5, globaliter : 508, batch_idx  : 23, triplet_loss : 0.04902764782309532
# epoch : 5, globaliter : 509, batch_idx  : 24, triplet_loss : 0.0758073627948761
# epoch : 5, globaliter : 510, batch_idx  : 25, triplet_loss : 0.05005098879337311
# epoch : 5, globaliter : 511, batch_idx  : 26, triplet_loss : 0.06974317133426666
# epoch : 5, globaliter : 512, batch_idx  : 27, triplet_loss : 0.07565552741289139
# epoch : 5, globaliter : 513, batch_idx  : 28, triplet_loss : 0.05149970203638077
# epoch : 5, globaliter : 514, batch_idx  : 29, triplet_loss : 0.04892002046108246
# epoch : 5, globaliter : 515, batch_idx  : 30, triplet_loss : 0.04500465840101242
# epoch : 5, globaliter : 516, batch_idx  : 31, triplet_loss : 0.05981975793838501
# epoch : 5, globaliter : 517, batch_idx  : 32, triplet_loss : 0.0648253932595253
# epoch : 5, globaliter : 518, batch_idx  : 33, triplet_loss : 0.03838932886719704
# epoch : 5, globaliter : 519, batch_idx  : 34, triplet_loss : 0.05863417312502861
# epoch : 5, globaliter : 520, batch_idx  : 35, triplet_loss : 0.0560542568564415
# epoch : 5, globaliter : 521, batch_idx  : 36, triplet_loss : 0.0490802563726902
# epoch : 5, globaliter : 522, batch_idx  : 37, triplet_loss : 0.06240260228514671
# epoch : 5, globaliter : 523, batch_idx  : 38, triplet_loss : 0.041244931519031525
# epoch : 5, globaliter : 524, batch_idx  : 39, triplet_loss : 0.05111314728856087
# epoch : 5, globaliter : 525, batch_idx  : 40, triplet_loss : 0.06668489426374435
# epoch : 5, globaliter : 526, batch_idx  : 41, triplet_loss : 0.05376634746789932
# epoch : 5, globaliter : 527, batch_idx  : 42, triplet_loss : 0.057656317949295044
# epoch : 5, globaliter : 528, batch_idx  : 43, triplet_loss : 0.05589203163981438
# epoch : 5, globaliter : 529, batch_idx  : 44, triplet_loss : 0.049329135566949844
# epoch : 5, globaliter : 530, batch_idx  : 45, triplet_loss : 0.04196833819150925
# epoch : 5, globaliter : 531, batch_idx  : 46, triplet_loss : 0.0639912560582161
# epoch : 5, globaliter : 532, batch_idx  : 47, triplet_loss : 0.03440757468342781
# epoch : 5, globaliter : 533, batch_idx  : 48, triplet_loss : 0.027609193697571754
# epoch : 5, globaliter : 534, batch_idx  : 49, triplet_loss : 0.040095116943120956
# epoch : 5, globaliter : 535, batch_idx  : 50, triplet_loss : 0.042185332626104355
# epoch : 5, globaliter : 536, batch_idx  : 51, triplet_loss : 0.039173226803541183
# epoch : 5, globaliter : 537, batch_idx  : 52, triplet_loss : 0.02285894565284252
# epoch : 5, globaliter : 538, batch_idx  : 53, triplet_loss : 0.054814428091049194
# epoch : 5, globaliter : 539, batch_idx  : 54, triplet_loss : 0.04719126969575882
# epoch : 5, globaliter : 540, batch_idx  : 55, triplet_loss : 0.0726904422044754
# epoch : 5, globaliter : 541, batch_idx  : 56, triplet_loss : 0.0398559607565403
# epoch : 5, globaliter : 542, batch_idx  : 57, triplet_loss : 0.057025909423828125
# epoch : 5, globaliter : 543, batch_idx  : 58, triplet_loss : 0.057270362973213196
# epoch : 5, globaliter : 544, batch_idx  : 59, triplet_loss : 0.055230963975191116
# epoch : 5, globaliter : 545, batch_idx  : 60, triplet_loss : 0.046647001057863235
# epoch : 5, globaliter : 546, batch_idx  : 61, triplet_loss : 0.05451807379722595
# epoch : 5, globaliter : 547, batch_idx  : 62, triplet_loss : 0.06269064545631409
# epoch : 5, globaliter : 548, batch_idx  : 63, triplet_loss : 0.03140351176261902
# epoch : 5, globaliter : 549, batch_idx  : 64, triplet_loss : 0.03906022757291794
# epoch : 5, globaliter : 550, batch_idx  : 65, triplet_loss : 0.05098128318786621
# epoch : 5, globaliter : 551, batch_idx  : 66, triplet_loss : 0.06524547189474106
# epoch : 5, globaliter : 552, batch_idx  : 67, triplet_loss : 0.04259542003273964
# epoch : 5, globaliter : 553, batch_idx  : 68, triplet_loss : 0.04109269008040428
# epoch : 5, globaliter : 554, batch_idx  : 69, triplet_loss : 0.06595736742019653
# epoch : 5, globaliter : 555, batch_idx  : 70, triplet_loss : 0.08499301224946976
# epoch : 5, globaliter : 556, batch_idx  : 71, triplet_loss : 0.05450141429901123
# epoch : 5, globaliter : 557, batch_idx  : 72, triplet_loss : 0.03182431310415268
# epoch : 5, globaliter : 558, batch_idx  : 73, triplet_loss : 0.05801395699381828
# epoch : 5, globaliter : 559, batch_idx  : 74, triplet_loss : 0.07009240239858627
# epoch : 5, globaliter : 560, batch_idx  : 75, triplet_loss : 0.05403278023004532
# epoch : 5, globaliter : 561, batch_idx  : 76, triplet_loss : 0.04308019578456879
# epoch : 5, globaliter : 562, batch_idx  : 77, triplet_loss : 0.03559799864888191
# epoch : 5, globaliter : 563, batch_idx  : 78, triplet_loss : 0.06372297555208206
# epoch : 5, globaliter : 564, batch_idx  : 79, triplet_loss : 0.029078219085931778
# epoch : 5, globaliter : 565, batch_idx  : 80, triplet_loss : 0.04837403446435928
# epoch : 5, globaliter : 566, batch_idx  : 81, triplet_loss : 0.0644940659403801
# epoch : 5, globaliter : 567, batch_idx  : 82, triplet_loss : 0.042413078248500824
# epoch : 5, globaliter : 568, batch_idx  : 83, triplet_loss : 0.040917057543992996
# epoch : 5, globaliter : 569, batch_idx  : 84, triplet_loss : 0.028000622987747192
# epoch : 5, globaliter : 570, batch_idx  : 85, triplet_loss : 0.057971686124801636
# epoch : 5, globaliter : 571, batch_idx  : 86, triplet_loss : 0.025376947596669197
# epoch : 5, globaliter : 572, batch_idx  : 87, triplet_loss : 0.061087921261787415
# epoch : 5, globaliter : 573, batch_idx  : 88, triplet_loss : 0.07410453259944916
# epoch : 5, globaliter : 574, batch_idx  : 89, triplet_loss : 0.07553558796644211
# epoch : 5, globaliter : 575, batch_idx  : 90, triplet_loss : 0.034178510308265686
# epoch : 5, globaliter : 576, batch_idx  : 91, triplet_loss : 0.025245394557714462
# epoch : 5, globaliter : 577, batch_idx  : 92, triplet_loss : 0.05241318419575691
# epoch : 5, globaliter : 578, batch_idx  : 93, triplet_loss : 0.08718479424715042
# epoch : 5, globaliter : 579, batch_idx  : 94, triplet_loss : 0.06609250605106354
# epoch : 5, globaliter : 580, batch_idx  : 95, triplet_loss : 0.07116968184709549
# epoch : 5, globaliter : 581, batch_idx  : 96, triplet_loss : 0.04276244342327118
# epoch : 6, globaliter : 582, batch_idx  : 0, triplet_loss : 0.05405719578266144
# epoch : 6, globaliter : 583, batch_idx  : 1, triplet_loss : 0.06104256212711334
# epoch : 6, globaliter : 584, batch_idx  : 2, triplet_loss : 0.08498839288949966
# epoch : 6, globaliter : 585, batch_idx  : 3, triplet_loss : 0.041001398116350174
# epoch : 6, globaliter : 586, batch_idx  : 4, triplet_loss : 0.07005742937326431
# epoch : 6, globaliter : 587, batch_idx  : 5, triplet_loss : 0.07581208646297455
# epoch : 6, globaliter : 588, batch_idx  : 6, triplet_loss : 0.04361593723297119
# epoch : 6, globaliter : 589, batch_idx  : 7, triplet_loss : 0.05741293728351593
# epoch : 6, globaliter : 590, batch_idx  : 8, triplet_loss : 0.0405995212495327
# epoch : 6, globaliter : 591, batch_idx  : 9, triplet_loss : 0.03776993975043297
# epoch : 6, globaliter : 592, batch_idx  : 10, triplet_loss : 0.025248954072594643
# epoch : 6, globaliter : 593, batch_idx  : 11, triplet_loss : 0.03871072828769684
# epoch : 6, globaliter : 594, batch_idx  : 12, triplet_loss : 0.06196201592683792
# ...
# epoch : 47, globaliter : 4646, batch_idx  : 87, triplet_loss : 0.0
# epoch : 47, globaliter : 4647, batch_idx  : 88, triplet_loss : 0.011883656494319439
# epoch : 47, globaliter : 4648, batch_idx  : 89, triplet_loss : 0.0010518133640289307
# epoch : 47, globaliter : 4649, batch_idx  : 90, triplet_loss : 0.002554081380367279
# epoch : 47, globaliter : 4650, batch_idx  : 91, triplet_loss : 0.0002680346369743347
# epoch : 47, globaliter : 4651, batch_idx  : 92, triplet_loss : 0.0
# epoch : 47, globaliter : 4652, batch_idx  : 93, triplet_loss : 0.009463301859796047
# epoch : 47, globaliter : 4653, batch_idx  : 94, triplet_loss : 0.0055124289356172085
# epoch : 47, globaliter : 4654, batch_idx  : 95, triplet_loss : 0.0
# epoch : 47, globaliter : 4655, batch_idx  : 96, triplet_loss : 0.002948291599750519
# epoch : 48, globaliter : 4656, batch_idx  : 0, triplet_loss : 0.00010684877634048462
# epoch : 48, globaliter : 4657, batch_idx  : 1, triplet_loss : 0.0
# epoch : 48, globaliter : 4658, batch_idx  : 2, triplet_loss : 0.0
# epoch : 48, globaliter : 4659, batch_idx  : 3, triplet_loss : 0.0019257385283708572
# epoch : 48, globaliter : 4660, batch_idx  : 4, triplet_loss : 0.006551904138177633
# epoch : 48, globaliter : 4661, batch_idx  : 5, triplet_loss : 0.0217493437230587
# epoch : 48, globaliter : 4662, batch_idx  : 6, triplet_loss : 0.0015040835132822394
# epoch : 48, globaliter : 4663, batch_idx  : 7, triplet_loss : 0.008954931050539017
# epoch : 48, globaliter : 4664, batch_idx  : 8, triplet_loss : 0.006254886742681265
# epoch : 48, globaliter : 4665, batch_idx  : 9, triplet_loss : 0.0020695559214800596
# epoch : 48, globaliter : 4666, batch_idx  : 10, triplet_loss : 0.005154692567884922
# epoch : 48, globaliter : 4667, batch_idx  : 11, triplet_loss : 0.005417559761554003
# epoch : 48, globaliter : 4668, batch_idx  : 12, triplet_loss : 0.0012321807444095612
# epoch : 48, globaliter : 4669, batch_idx  : 13, triplet_loss : 0.0
# epoch : 48, globaliter : 4670, batch_idx  : 14, triplet_loss : 0.003773316042497754
# epoch : 48, globaliter : 4671, batch_idx  : 15, triplet_loss : 0.001109437202103436
# epoch : 48, globaliter : 4672, batch_idx  : 16, triplet_loss : 0.0012591847917065024
# epoch : 48, globaliter : 4673, batch_idx  : 17, triplet_loss : 0.0
# epoch : 48, globaliter : 4674, batch_idx  : 18, triplet_loss : 0.005081511568278074
# epoch : 48, globaliter : 4675, batch_idx  : 19, triplet_loss : 0.0
# epoch : 48, globaliter : 4676, batch_idx  : 20, triplet_loss : 0.0020994218066334724
# epoch : 48, globaliter : 4677, batch_idx  : 21, triplet_loss : 0.001697741448879242
# epoch : 48, globaliter : 4678, batch_idx  : 22, triplet_loss : 0.0032450594007968903
# epoch : 48, globaliter : 4679, batch_idx  : 23, triplet_loss : 0.0
# epoch : 48, globaliter : 4680, batch_idx  : 24, triplet_loss : 0.0005912929773330688
# epoch : 48, globaliter : 4681, batch_idx  : 25, triplet_loss : 0.0030934810638427734
# epoch : 48, globaliter : 4682, batch_idx  : 26, triplet_loss : 0.00016698986291885376
# epoch : 48, globaliter : 4683, batch_idx  : 27, triplet_loss : 0.00877389032393694
# epoch : 48, globaliter : 4684, batch_idx  : 28, triplet_loss : 0.028252746909856796
# epoch : 48, globaliter : 4685, batch_idx  : 29, triplet_loss : 0.007161800283938646
# epoch : 48, globaliter : 4686, batch_idx  : 30, triplet_loss : 0.007068426813930273
# epoch : 48, globaliter : 4687, batch_idx  : 31, triplet_loss : 0.001290932297706604
# epoch : 48, globaliter : 4688, batch_idx  : 32, triplet_loss : 0.004189864732325077
# epoch : 48, globaliter : 4689, batch_idx  : 33, triplet_loss : 0.0
# epoch : 48, globaliter : 4690, batch_idx  : 34, triplet_loss : 6.160885095596313e-05
# epoch : 48, globaliter : 4691, batch_idx  : 35, triplet_loss : 0.002530887722969055
# epoch : 48, globaliter : 4692, batch_idx  : 36, triplet_loss : 0.0006288811564445496
# epoch : 48, globaliter : 4693, batch_idx  : 37, triplet_loss : 0.009192799217998981
# epoch : 48, globaliter : 4694, batch_idx  : 38, triplet_loss : 0.0
# epoch : 48, globaliter : 4695, batch_idx  : 39, triplet_loss : 0.003458383260294795
# epoch : 48, globaliter : 4696, batch_idx  : 40, triplet_loss : 0.003779379650950432
# epoch : 48, globaliter : 4697, batch_idx  : 41, triplet_loss : 0.0
# epoch : 48, globaliter : 4698, batch_idx  : 42, triplet_loss : 0.0
# epoch : 48, globaliter : 4699, batch_idx  : 43, triplet_loss : 0.0003486946225166321
# epoch : 48, globaliter : 4700, batch_idx  : 44, triplet_loss : 0.01584845781326294
# epoch : 48, globaliter : 4701, batch_idx  : 45, triplet_loss : 0.0008389167487621307
# epoch : 48, globaliter : 4702, batch_idx  : 46, triplet_loss : 0.0035613086074590683
# epoch : 48, globaliter : 4703, batch_idx  : 47, triplet_loss : 0.0012171640992164612
# epoch : 48, globaliter : 4704, batch_idx  : 48, triplet_loss : 0.003129045944660902
# epoch : 48, globaliter : 4705, batch_idx  : 49, triplet_loss : 0.0
# epoch : 48, globaliter : 4706, batch_idx  : 50, triplet_loss : 0.0004284903407096863
# epoch : 48, globaliter : 4707, batch_idx  : 51, triplet_loss : 0.0
# epoch : 48, globaliter : 4708, batch_idx  : 52, triplet_loss : 0.0
# epoch : 48, globaliter : 4709, batch_idx  : 53, triplet_loss : 0.062448322772979736
# epoch : 48, globaliter : 4710, batch_idx  : 54, triplet_loss : 0.030962340533733368
# epoch : 48, globaliter : 4711, batch_idx  : 55, triplet_loss : 0.0
# epoch : 48, globaliter : 4712, batch_idx  : 56, triplet_loss : 0.004563853144645691
# epoch : 48, globaliter : 4713, batch_idx  : 57, triplet_loss : 0.0
# epoch : 48, globaliter : 4714, batch_idx  : 58, triplet_loss : 0.0
# epoch : 48, globaliter : 4715, batch_idx  : 59, triplet_loss : 0.0
# epoch : 48, globaliter : 4716, batch_idx  : 60, triplet_loss : 0.0
# epoch : 48, globaliter : 4717, batch_idx  : 61, triplet_loss : 0.0
# epoch : 48, globaliter : 4718, batch_idx  : 62, triplet_loss : 0.005005434155464172
# epoch : 48, globaliter : 4719, batch_idx  : 63, triplet_loss : 0.0016077744076028466
# epoch : 48, globaliter : 4720, batch_idx  : 64, triplet_loss : 0.024131201207637787
# epoch : 48, globaliter : 4721, batch_idx  : 65, triplet_loss : 0.0
# epoch : 48, globaliter : 4722, batch_idx  : 66, triplet_loss : 0.006512357387691736
# epoch : 48, globaliter : 4723, batch_idx  : 67, triplet_loss : 0.0020110588520765305
# epoch : 48, globaliter : 4724, batch_idx  : 68, triplet_loss : 0.005158430431038141
# epoch : 48, globaliter : 4725, batch_idx  : 69, triplet_loss : 0.006071321666240692
# epoch : 48, globaliter : 4726, batch_idx  : 70, triplet_loss : 0.0
# epoch : 48, globaliter : 4727, batch_idx  : 71, triplet_loss : 0.011349556967616081
# epoch : 48, globaliter : 4728, batch_idx  : 72, triplet_loss : 0.0030379060190171003
# epoch : 48, globaliter : 4729, batch_idx  : 73, triplet_loss : 0.011672936379909515
# epoch : 48, globaliter : 4730, batch_idx  : 74, triplet_loss : 0.001147981733083725
# epoch : 48, globaliter : 4731, batch_idx  : 75, triplet_loss : 0.0013408008962869644
# epoch : 48, globaliter : 4732, batch_idx  : 76, triplet_loss : 0.0007490627467632294
# epoch : 48, globaliter : 4733, batch_idx  : 77, triplet_loss : 0.0
# epoch : 48, globaliter : 4734, batch_idx  : 78, triplet_loss : 0.0006925612688064575
# epoch : 48, globaliter : 4735, batch_idx  : 79, triplet_loss : 0.002638045698404312
# epoch : 48, globaliter : 4736, batch_idx  : 80, triplet_loss : 0.007099265698343515
# epoch : 48, globaliter : 4737, batch_idx  : 81, triplet_loss : 0.0
# epoch : 48, globaliter : 4738, batch_idx  : 82, triplet_loss : 0.020567717030644417
# epoch : 48, globaliter : 4739, batch_idx  : 83, triplet_loss : 0.0005640015006065369
# epoch : 48, globaliter : 4740, batch_idx  : 84, triplet_loss : 0.0
# epoch : 48, globaliter : 4741, batch_idx  : 85, triplet_loss : 0.03600951284170151
# epoch : 48, globaliter : 4742, batch_idx  : 86, triplet_loss : 0.01434846967458725
# epoch : 48, globaliter : 4743, batch_idx  : 87, triplet_loss : 0.007674050517380238
# epoch : 48, globaliter : 4744, batch_idx  : 88, triplet_loss : 0.0
# epoch : 48, globaliter : 4745, batch_idx  : 89, triplet_loss : 0.0
# epoch : 48, globaliter : 4746, batch_idx  : 90, triplet_loss : 0.00773759325966239
# epoch : 48, globaliter : 4747, batch_idx  : 91, triplet_loss : 0.003151567652821541
# epoch : 48, globaliter : 4748, batch_idx  : 92, triplet_loss : 0.013405808247625828
# epoch : 48, globaliter : 4749, batch_idx  : 93, triplet_loss : 0.0
# epoch : 48, globaliter : 4750, batch_idx  : 94, triplet_loss : 0.0
# epoch : 48, globaliter : 4751, batch_idx  : 95, triplet_loss : 0.00028307363390922546
# epoch : 48, globaliter : 4752, batch_idx  : 96, triplet_loss : 0.007720597553998232
# epoch : 49, globaliter : 4753, batch_idx  : 0, triplet_loss : 0.02394689805805683
# epoch : 49, globaliter : 4754, batch_idx  : 1, triplet_loss : 3.16128134727478e-05
# epoch : 49, globaliter : 4755, batch_idx  : 2, triplet_loss : 0.06036446616053581
# epoch : 49, globaliter : 4756, batch_idx  : 3, triplet_loss : 0.0011232694378122687
# epoch : 49, globaliter : 4757, batch_idx  : 4, triplet_loss : 0.0038224905729293823
# epoch : 49, globaliter : 4758, batch_idx  : 5, triplet_loss : 0.0
# epoch : 49, globaliter : 4759, batch_idx  : 6, triplet_loss : 0.006812927313148975
# epoch : 49, globaliter : 4760, batch_idx  : 7, triplet_loss : 0.0
# epoch : 49, globaliter : 4761, batch_idx  : 8, triplet_loss : 0.0224099513143301
# epoch : 49, globaliter : 4762, batch_idx  : 9, triplet_loss : 0.00024531036615371704
# epoch : 49, globaliter : 4763, batch_idx  : 10, triplet_loss : 0.0
# epoch : 49, globaliter : 4764, batch_idx  : 11, triplet_loss : 0.0
# epoch : 49, globaliter : 4765, batch_idx  : 12, triplet_loss : 0.01763424091041088
# epoch : 49, globaliter : 4766, batch_idx  : 13, triplet_loss : 0.003748399903997779
# epoch : 49, globaliter : 4767, batch_idx  : 14, triplet_loss : 0.0
# epoch : 49, globaliter : 4768, batch_idx  : 15, triplet_loss : 0.0008234605193138123
# epoch : 49, globaliter : 4769, batch_idx  : 16, triplet_loss : 0.03400150686502457
# epoch : 49, globaliter : 4770, batch_idx  : 17, triplet_loss : 0.015339575707912445
# epoch : 49, globaliter : 4771, batch_idx  : 18, triplet_loss : 0.0
# epoch : 49, globaliter : 4772, batch_idx  : 19, triplet_loss : 0.0
# epoch : 49, globaliter : 4773, batch_idx  : 20, triplet_loss : 0.004620748106390238
# epoch : 49, globaliter : 4774, batch_idx  : 21, triplet_loss : 0.001562065095640719
# epoch : 49, globaliter : 4775, batch_idx  : 22, triplet_loss : 0.0006102323532104492
# epoch : 49, globaliter : 4776, batch_idx  : 23, triplet_loss : 0.0022288199979811907
# epoch : 49, globaliter : 4777, batch_idx  : 24, triplet_loss : 0.0
# epoch : 49, globaliter : 4778, batch_idx  : 25, triplet_loss : 0.0020230188965797424
# epoch : 49, globaliter : 4779, batch_idx  : 26, triplet_loss : 0.0
# epoch : 49, globaliter : 4780, batch_idx  : 27, triplet_loss : 0.0
# epoch : 49, globaliter : 4781, batch_idx  : 28, triplet_loss : 0.0
# epoch : 49, globaliter : 4782, batch_idx  : 29, triplet_loss : 0.0076994337141513824
# epoch : 49, globaliter : 4783, batch_idx  : 30, triplet_loss : 0.003465179353952408
# epoch : 49, globaliter : 4784, batch_idx  : 31, triplet_loss : 0.0
# epoch : 49, globaliter : 4785, batch_idx  : 32, triplet_loss : 0.002495989203453064
# epoch : 49, globaliter : 4786, batch_idx  : 33, triplet_loss : 0.0021472126245498657
# epoch : 49, globaliter : 4787, batch_idx  : 34, triplet_loss : 0.0016001593321561813
# epoch : 49, globaliter : 4788, batch_idx  : 35, triplet_loss : 0.006243348121643066
# epoch : 49, globaliter : 4789, batch_idx  : 36, triplet_loss : 0.0
# epoch : 49, globaliter : 4790, batch_idx  : 37, triplet_loss : 0.0026991094928234816
# epoch : 49, globaliter : 4791, batch_idx  : 38, triplet_loss : 0.012096939608454704
# epoch : 49, globaliter : 4792, batch_idx  : 39, triplet_loss : 0.002301386557519436
# epoch : 49, globaliter : 4793, batch_idx  : 40, triplet_loss : 0.00067950040102005
# epoch : 49, globaliter : 4794, batch_idx  : 41, triplet_loss : 0.013827276416122913
# epoch : 49, globaliter : 4795, batch_idx  : 42, triplet_loss : 0.0013246238231658936
# epoch : 49, globaliter : 4796, batch_idx  : 43, triplet_loss : 0.0020539865363389254
# epoch : 49, globaliter : 4797, batch_idx  : 44, triplet_loss : 0.008683716878294945
# epoch : 49, globaliter : 4798, batch_idx  : 45, triplet_loss : 0.0
# epoch : 49, globaliter : 4799, batch_idx  : 46, triplet_loss : 0.0014986470341682434
# epoch : 49, globaliter : 4800, batch_idx  : 47, triplet_loss : 0.0
# epoch : 49, globaliter : 4801, batch_idx  : 48, triplet_loss : 0.0039015961810946465
# epoch : 49, globaliter : 4802, batch_idx  : 49, triplet_loss : 0.01117236539721489
# epoch : 49, globaliter : 4803, batch_idx  : 50, triplet_loss : 0.002164151519536972
# epoch : 49, globaliter : 4804, batch_idx  : 51, triplet_loss : 0.005443934351205826
# epoch : 49, globaliter : 4805, batch_idx  : 52, triplet_loss : 0.0
# epoch : 49, globaliter : 4806, batch_idx  : 53, triplet_loss : 0.008549842983484268
# epoch : 49, globaliter : 4807, batch_idx  : 54, triplet_loss : 0.006162628531455994
# epoch : 49, globaliter : 4808, batch_idx  : 55, triplet_loss : 0.01317519135773182
# epoch : 49, globaliter : 4809, batch_idx  : 56, triplet_loss : 0.010720601305365562
# epoch : 49, globaliter : 4810, batch_idx  : 57, triplet_loss : 0.0
# epoch : 49, globaliter : 4811, batch_idx  : 58, triplet_loss : 0.0
# epoch : 49, globaliter : 4812, batch_idx  : 59, triplet_loss : 0.002939654514193535
# epoch : 49, globaliter : 4813, batch_idx  : 60, triplet_loss : 0.0
# epoch : 49, globaliter : 4814, batch_idx  : 61, triplet_loss : 0.0011529885232448578
# epoch : 49, globaliter : 4815, batch_idx  : 62, triplet_loss : 0.0017217490822076797
# epoch : 49, globaliter : 4816, batch_idx  : 63, triplet_loss : 0.0
# epoch : 49, globaliter : 4817, batch_idx  : 64, triplet_loss : 0.003944049123674631
# epoch : 49, globaliter : 4818, batch_idx  : 65, triplet_loss : 0.0
# epoch : 49, globaliter : 4819, batch_idx  : 66, triplet_loss : 0.0
# epoch : 49, globaliter : 4820, batch_idx  : 67, triplet_loss : 0.0
# epoch : 49, globaliter : 4821, batch_idx  : 68, triplet_loss : 0.0
# epoch : 49, globaliter : 4822, batch_idx  : 69, triplet_loss : 0.008266844786703587
# epoch : 49, globaliter : 4823, batch_idx  : 70, triplet_loss : 0.0027692592702805996
# epoch : 49, globaliter : 4824, batch_idx  : 71, triplet_loss : 0.0
# epoch : 49, globaliter : 4825, batch_idx  : 72, triplet_loss : 0.0018555328715592623
# epoch : 49, globaliter : 4826, batch_idx  : 73, triplet_loss : 0.0
# epoch : 49, globaliter : 4827, batch_idx  : 74, triplet_loss : 0.0
# epoch : 49, globaliter : 4828, batch_idx  : 75, triplet_loss : 0.0
# epoch : 49, globaliter : 4829, batch_idx  : 76, triplet_loss : 0.019522788003087044
# epoch : 49, globaliter : 4830, batch_idx  : 77, triplet_loss : 0.0025748908519744873
# epoch : 49, globaliter : 4831, batch_idx  : 78, triplet_loss : 0.0
# epoch : 49, globaliter : 4832, batch_idx  : 79, triplet_loss : 0.002755485475063324
# epoch : 49, globaliter : 4833, batch_idx  : 80, triplet_loss : 0.0
# epoch : 49, globaliter : 4834, batch_idx  : 81, triplet_loss : 0.007507775444537401
# epoch : 49, globaliter : 4835, batch_idx  : 82, triplet_loss : 0.0
# epoch : 49, globaliter : 4836, batch_idx  : 83, triplet_loss : 0.0
# epoch : 49, globaliter : 4837, batch_idx  : 84, triplet_loss : 0.01971016451716423
# epoch : 49, globaliter : 4838, batch_idx  : 85, triplet_loss : 0.0021844401489943266
# epoch : 49, globaliter : 4839, batch_idx  : 86, triplet_loss : 0.0007797926664352417
# epoch : 49, globaliter : 4840, batch_idx  : 87, triplet_loss : 0.0011231973767280579
# epoch : 49, globaliter : 4841, batch_idx  : 88, triplet_loss : 0.0
# epoch : 49, globaliter : 4842, batch_idx  : 89, triplet_loss : 0.0
# epoch : 49, globaliter : 4843, batch_idx  : 90, triplet_loss : 0.0
# epoch : 49, globaliter : 4844, batch_idx  : 91, triplet_loss : 0.0
# epoch : 49, globaliter : 4845, batch_idx  : 92, triplet_loss : 0.0007749252836219966
# epoch : 49, globaliter : 4846, batch_idx  : 93, triplet_loss : 0.0033721127547323704
# epoch : 49, globaliter : 4847, batch_idx  : 94, triplet_loss : 0.0063436273485422134
# epoch : 49, globaliter : 4848, batch_idx  : 95, triplet_loss : 0.0
# epoch : 49, globaliter : 4849, batch_idx  : 96, triplet_loss : 0.0

# %% [markdown]
# ![111](https://user-images.githubusercontent.com/44772344/59032140-850edf00-88a0-11e9-90f6-925901406168.PNG)
#
# ## 이를 텐서보드로 확인하면 다음과 같습니다.
#
#
# ## 이미 학습한 모델을 받는다면 싶다면 다음 명령어를 실행해 주세요
#
# !wget -O /content/model_47.pt "https://www.dropbox.com/s/g5nwt0do351huc2/model_47.pt?dl=1"</br>
# !wget -O /content/model_48.pt "https://www.dropbox.com/s/86qev1vgg545ee4/model_48.pt?dl=1"</br>
# !wget -O /content/model_49.pt "https://www.dropbox.com/s/obceyvw3d40rsxo/model_49.pt?dl=1"</br>

# %%
state_dict = torch.load('./model_49.pt')
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
out_train_image = model(bef_train_image.cuda())
X_train = out_train_image
Y_train = bef_train_label

# %%
for test_image,test_label in test_data_loader :  
  output_test = model(test_image.cuda())
  X_test = output_test
  Y_test = test_label

# %%
from PIL import Image
from sklearn import (manifold, datasets, decomposition, ensemble,
                     discriminant_analysis, random_projection)
import torchvision.transforms.functional as Function
from IPython.display import display
from time import time
from matplotlib import offsetbox
from sklearn.neighbors import DistanceMetric
# %matplotlib inline

def plot_embedding(X, y_t, title=None):

    y = y_t.numpy()
    
    x_min, x_max = np.min(X, 0), np.max(X, 0)
    X = (X - x_min) / (x_max - x_min)

    plt.figure()
    for i in range(X.shape[0]):
      if i == 776 :
        plt.text(X[i, 0], X[i, 1], str(y[i]),
               color='black',
               fontdict={'weight': 'bold', 'size': 30})
      else :
        plt.text(X[i, 0], X[i, 1], str(y[i]),
                 color=plt.cm.Set1(y[i] / 10.),
                 fontdict={'weight': 'bold', 'size': 9})

    plt.xticks([]), plt.yticks([])
    if title is not None:
        plt.title(title)

# %%
# 0~98
check_index = 80

# %%
test_image.shape
test_label.shape
# Out:
# torch.Size([98])

# %%
image_query = X_test[check_index].view(1,-1)
label_query = Y_test[check_index].view(1)
X_total= torch.cat([X_train, image_query], dim=0)
Y_total= torch.cat([Y_train, label_query], dim=0)

test_img = Function.to_pil_image(test_image[check_index])
print('테스트할 이미지 : {}'.format(test_label[check_index].item()))
display(test_img)
# Out:
# 테스트할 이미지 : 4
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F5BD6BE7D50>

# %%
tsne = manifold.TSNE(n_components=2, init='pca', random_state=0)
X_tsne = tsne.fit_transform(X_total.cpu().detach().numpy())

pairwise_dist_t = _pairwise_distance(X_total)
pairwise_dist_n = pairwise_dist_t.cpu().detach().numpy()

pairwise_dist_sort = np.sort(pairwise_dist_n[-1][:-1])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,

# %%
test_img = Function.to_pil_image(test_image[check_index])
print('들어온 이미지 : {}\n'.format(test_label[check_index].item()))
display(test_img)
print("\n")

for ii in range(5):
  idx = np.where( pairwise_dist_n[-1] == pairwise_dist_sort[ii])
  print('{} 번째로 비슷한 {} 번째 이미지 : '.format(ii+1,idx[0][0]))
  img = Function.to_pil_image(bef_train_image[idx[0][0]])
  #     img.save('test{}_{}.png'.format(Y_total[ii],ii))
  display(img)
  print("\n")
# Out:
# 들어온 이미지 : 4
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F5C540C8BD0>
# 1 번째로 비슷한 570 번째 이미지 :
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F5C540C8410>
# 2 번째로 비슷한 565 번째 이미지 :
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F5C540E8A10>
# 3 번째로 비슷한 610 번째 이미지 :
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F5C540E8DD0>
# 4 번째로 비슷한 667 번째 이미지 :
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F5C540E8B10>
# 5 번째로 비슷한 640 번째 이미지 :
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F5C540C8050>

# %% [markdown]
# ## 해당 그래프 그리는 방법은 TFKR 김대하님의 Github를 참고했습니다.
#
# # [바로가기](https://github.com/kdhht2334/Triplet_loss_for_image_retrieval?fbclid=IwAR2sBMRu6ae7XCMBfotevsttCDQGV5DcUvBLkUOS93izbpXlR7JrRzkJYvc)

# %%
plot_embedding(X_tsne, Y_total,"Sejong Landmark data set")
plt.show()

# %%
X_tsne.shape
# Out:
# (777, 2)
